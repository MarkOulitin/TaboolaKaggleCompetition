# %%
import os
import json
import pandas as pd
import scipy as sp
from sklearn.preprocessing import LabelEncoder 
from matplotlib import pyplot as plt

from tqdm.auto import tqdm
import numpy as np
import datetime
import pickle
ASSAF_STORAGE = '/sise/assafzar-group/assafzar/mark/taboola-competition/'

# %% [markdown]
# ## Subsetting the data - taking X last days

# %% [markdown]
# Loading all previously normalized data, now fits into RAM

# %%
from pprint import pprint
assaf_path = '/sise/assafzar-group/assafzar/mark/taboola-competition'
def read_all_data():
    pre_path = f'{assaf_path}/normalized_train_data'
    paths = []
    dirs = os.listdir(pre_path)
    for dir in dirs:
        filenames = os.listdir(f'{pre_path}/{dir}')
        paths += [f'{pre_path}/{dir}/{filename}' for filename in filenames]
    paths = sorted(paths)
    dfs = []
    for filepath in tqdm(paths, desc='Loading data'):
        df = pd.read_csv(filepath)
        df.drop(columns=['Unnamed: 0'], inplace=True)
        dfs.append(df)
    dfs = pd.concat(dfs)
    return dfs
data = read_all_data()
# Out:
# Loading data: 100%|██████████| 69/69 [01:37<00:00,  1.42s/it]

# %% [markdown]
# Subsetting the data by a temporal threshold - final model was on the last 5 days of the data

# %%
max_timestamp = data['page_view_start_time'].max()
five_days_ago = (datetime.datetime.fromtimestamp(max_timestamp/1000) - datetime.timedelta(days=5)).replace(hour=0, minute=0, second=0, microsecond=0)
five_days_ago = int(datetime.datetime.timestamp(five_days_ago) * 1000)
last_x_days = data[data['page_view_start_time'] >= five_days_ago]
last_x_days.shape
# Out:
# (10926180, 23)

# %%
features = [
    'page_view_start_time', 'user_id_hash', 'target_id_hash',
    'syndicator_id_hash', 'campaign_id_hash', 'empiric_calibrated_recs',
    'empiric_clicks', 'target_item_taxonomy', 'placement_id_hash',
    'user_recs', 'user_clicks', 'user_target_recs', 'publisher_id_hash',
    'source_id_hash', 'source_item_type', 'browser_platform', 'os_family',
    'country_code', 'region', 'day_of_week', 'time_of_day', 'gmt_offset'
]

# %% [markdown]
# Loading the encoders to translate the data back from labels

# %%
def load_encoders(features):
    column_encoders = []
    for feature in features:
        with open(f'{assaf_path}/label_encoders/{feature}.pickle', 'rb') as handle:
            encoder = pickle.load(handle)
        column_encoders.append((feature, encoder))
    return column_encoders

features_string_categories = [
    'user_id_hash',
    'target_id_hash',
    'syndicator_id_hash',
    'campaign_id_hash',
    'target_item_taxonomy',
    'placement_id_hash',
    'publisher_id_hash',
    'source_id_hash',
    'source_item_type',
    'browser_platform',
    'country_code',
    'region',
]
column_encoders = load_encoders(features_string_categories)
# Out:
# /home/noysal/.conda/envs/py39_torch/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.2.2 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %% [markdown]
# Recontructing the subset back to hashed format

# %%
def reconstruct():
    df = last_x_days.copy(deep=True)
    for column, encoder in tqdm(column_encoders):
        df[column] = encoder.inverse_transform(df[column].to_list())
    return df
last_x_days_recon = reconstruct()
last_x_days_recon['country_code'].fillna('Null', inplace=True)
last_x_days_recon['region'].fillna('Null', inplace=True)
# Out:
# 100%|██████████| 12/12 [00:26<00:00,  2.19s/it]

# %% [markdown]
# # Contextual featuer extraction

# %%
from itertools import combinations

def categorize_time(dt):
    hour = dt.hour
    if 5 <= hour < 11:
        return "morning"
    elif 11 <= hour < 13:
        return "midday"
    elif 13 <= hour < 18:
        return "afternoon"
    elif 18 <= hour < 24:
        return "evening"
    else:  # Hour is between 00:00 and 05:00
        return "night"
    
def format_time_offset(t):
    if len(t) == 1:
        return '+00:00:00'
    elif len(t) == 2: 
        return f'{t}:00:00'
    else:
        return f'{t[:-2]}:{t[-2:]}:00'

def apply_gmt_offset():
    gmt_offsets = last_x_days_recon['gmt_offset'].replace(9999, 0).astype(str).apply(format_time_offset)
    dt_series = pd.to_datetime(last_x_days_recon['page_view_start_time'], unit='us')
    gmt_offsets = pd.to_timedelta(gmt_offsets)
    dt_with_offset = dt_series + gmt_offsets
    last_x_days_recon['local_day_part'] = dt_with_offset.apply(categorize_time)

def add_feature_ctr(feature_1):
    """
    reference:
    https://medium.com/unstructured/how-feature-engineering-can-help-you-do-well-in-a-kaggle-competition-part-ii-3645d92282b8
    """
    latest_views = last_x_days.iloc[last_x_days.groupby('target_id_hash')['page_view_start_time'].idxmax()]
    latest_views = last_x_days.drop_duplicates(subset='target_id_hash', keep='first')
    stats = latest_views.groupby(f'{feature_1}_id_hash').agg({'empiric_calibrated_recs': 'sum', 'target_id_hash': 'count'})
    average_views_of_distinct_ad = np.log2(stats['empiric_calibrated_recs'].sum() / stats['target_id_hash'].sum())
    average_views_of_distict_ad_in_feature = np.log2(1 + (stats['empiric_calibrated_recs'] / stats['target_id_hash']))
    stats[f'{feature_1}_ctr'] = np.minimum((average_views_of_distict_ad_in_feature / average_views_of_distinct_ad), 1)
    stats = stats.reset_index()[[f'{feature_1}_id_hash', f'{feature_1}_ctr']]
    temp_df = last_x_days[[f'{feature_1}_id_hash']].merge(stats, on=f'{feature_1}_id_hash', how='left')
    last_x_days_recon[f'{feature_1}_ctr'] = temp_df[f'{feature_1}_ctr']

def add_pair_feature_ctr(feature_1, feature_2):
    """
    reference:
    https://medium.com/unstructured/how-feature-engineering-can-help-you-do-well-in-a-kaggle-competition-part-ii-3645d92282b8
    """
    latest_views = last_x_days.iloc[last_x_days.groupby('target_id_hash')['page_view_start_time'].idxmax()]
    latest_views = last_x_days.drop_duplicates(subset='target_id_hash', keep='first')
    stats = latest_views.groupby([f'{feature_1}_id_hash', f'{feature_2}_id_hash']).agg({'empiric_calibrated_recs': 'sum', 'target_id_hash': 'count'})
    average_views_of_distinct_ad = np.log2(stats['empiric_calibrated_recs'].sum() / stats['target_id_hash'].sum())
    average_views_of_distict_ad_in_feature = np.log2(1 + (stats['empiric_calibrated_recs'] / stats['target_id_hash']))
    stats[f'{feature_1}_{feature_2}_ctr'] = np.minimum((average_views_of_distict_ad_in_feature / average_views_of_distinct_ad), 1)
    stats = stats.reset_index()[[f'{feature_1}_id_hash', f'{feature_2}_id_hash', f'{feature_1}_{feature_2}_ctr']]
    temp_df = last_x_days[[f'{feature_1}_id_hash', f'{feature_2}_id_hash']].merge(stats, on=[f'{feature_1}_id_hash', f'{feature_2}_id_hash'], how='left')
    last_x_days_recon[f'{feature_1}_{feature_2}_ctr'] = temp_df[f'{feature_1}_{feature_2}_ctr']

def generate_ctrs():
    # generate ctr for estimate for features_ctr
    features_ctr = ['campaign', 'syndicator', 'placement', 'publisher', 'source']
    for feature in features_ctr:
        add_feature_ctr(feature)
    # generate ctr for pair wise estimate
    for feature_1, feature_2 in list(combinations(features_ctr, 2)):
        add_pair_feature_ctr(feature_1, feature_2)

# generate general target item taxonomy
last_x_days_recon['target_item_taxonomy_upper'] = last_x_days_recon['target_item_taxonomy'].str.split('~').str[0]
# target item ctr
last_x_days_recon['target_item_ctr'] = last_x_days_recon['empiric_clicks'].divide(last_x_days_recon['empiric_calibrated_recs'], fill_value=0) 
# user ctr
last_x_days_recon['user_ctr'] = last_x_days_recon['user_clicks'].divide(last_x_days_recon['user_recs'], fill_value=0)
# target item frequency
last_x_days_recon['item_presented_to_user_frequency'] = last_x_days_recon['user_target_recs'].divide(last_x_days_recon['user_recs'], fill_value=0)
# aggregation
last_x_days_recon['item_be_clicked_by_user'] = last_x_days_recon['user_ctr'] * last_x_days_recon['target_item_ctr'] * last_x_days_recon['item_presented_to_user_frequency']
# take the timestamp, shift to the local time by gmt offset, look at the hour of the day and generate categorical feature "local part of the day"
apply_gmt_offset()
# binary feature for cold and warm user
last_x_days_recon['user_type'] = (last_x_days_recon['user_recs'] > 0).apply(lambda x: 'warm' if x else 'cold')
# generate "category ctr"
generate_ctrs()

# %%
last_x_days_recon.columns
# Out:
# Index(['page_view_start_time', 'user_id_hash', 'target_id_hash',
#        'syndicator_id_hash', 'campaign_id_hash', 'empiric_calibrated_recs',
#        'empiric_clicks', 'target_item_taxonomy', 'placement_id_hash',
#        'user_recs', 'user_clicks', 'user_target_recs', 'publisher_id_hash',
#        'source_id_hash', 'source_item_type', 'browser_platform', 'os_family',
#        'country_code', 'region', 'day_of_week', 'time_of_day', 'gmt_offset',
#        'is_click', 'target_item_taxonomy_upper', 'target_item_ctr', 'user_ctr',
#        'item_presented_to_user_frequency', 'item_be_clicked_by_user',
#        'local_day_part', 'user_type', 'campaign_ctr', 'syndicator_ctr',
#        'placement_ctr', 'publisher_ctr', 'source_ctr',
#        'campaign_syndicator_ctr', 'campaign_placement_ctr',
#        'campaign_publisher_ctr', 'campaign_source_ctr',
#        'syndicator_placement_ctr', 'syndicator_publisher_ctr',
#        'syndicator_source_ctr', 'placement_publisher_ctr',
#        'placement_source_ctr', 'publisher_source_ctr'],
#       dtype='object')

# %%
## Transforming to numpy for faster computation

last_x_days_features = last_x_days_recon[[
    # 'user_id_hash',
    # 'target_id_hash',
    'syndicator_id_hash',
    'campaign_id_hash',
    'empiric_calibrated_recs',
    'empiric_clicks',
    'target_item_taxonomy',
    'placement_id_hash',
    'user_recs',
    'user_clicks',
    'user_target_recs',
    'publisher_id_hash',
    'source_id_hash',
    'source_item_type',
    'browser_platform',
    'os_family',
    'country_code',
    'region',
    'day_of_week',
    'time_of_day',
    'gmt_offset',
    'target_item_taxonomy_upper',
    'target_item_ctr',
    'user_ctr',
    'item_presented_to_user_frequency',
    'item_be_clicked_by_user',
    'local_day_part',
    'user_type',
    'campaign_ctr',
    'syndicator_ctr',
    'placement_ctr',
    'publisher_ctr',
    'source_ctr',
    'campaign_syndicator_ctr',
    'campaign_placement_ctr',
    'campaign_publisher_ctr',
    'campaign_source_ctr',
    'syndicator_placement_ctr',
    'syndicator_publisher_ctr',
    'syndicator_source_ctr',
    'placement_publisher_ctr',
    'placement_source_ctr',
    'publisher_source_ctr',
]].to_numpy()
last_x_days_ground_truth = last_x_days_recon['is_click'].to_numpy()

# %%
# create a vector of indices for categorial features, so that catboost wont treat the labeled columns as numeric
features_type = {
    # 'user_id_hash': 'cat',
    # 'target_id_hash': 'cat',
    'syndicator_id_hash': 'cat',
    'campaign_id_hash': 'cat',
    'empiric_calibrated_recs': '',
    'empiric_clicks': '',
    'target_item_taxonomy': 'cat',
    'placement_id_hash': 'cat',
    'user_recs': '',
    'user_clicks': '',
    'user_target_recs': '',
    'publisher_id_hash': 'cat',
    'source_id_hash': 'cat',
    'source_item_type': 'cat',
    'browser_platform': 'cat',
    'os_family': 'cat',
    'country_code': 'cat',
    'region': 'cat',
    'day_of_week': '',
    'time_of_day': '',
    'gmt_offset': 'cat',
    'target_item_taxonomy_upper': 'cat',
    'target_item_ctr': '',
    'user_ctr': '',
    'item_presented_to_user_frequency': '',
    'item_be_clicked_by_user': '',
    'local_day_part': 'cat',
    'user_type': 'cat',
    'campaign_ctr': '',
    'syndicator_ctr': '',
    'placement_ctr': '',
    'publisher_ctr': '',
    'source_ctr': '',
    'campaign_syndicator_ctr': '',
    'campaign_placement_ctr': '',
    'campaign_publisher_ctr': '',
    'campaign_source_ctr': '',
    'syndicator_placement_ctr': '',
    'syndicator_publisher_ctr': '',
    'syndicator_source_ctr': '',
    'placement_publisher_ctr': '',
    'placement_source_ctr': '',
    'publisher_source_ctr': '',
}
def temp():
    cat_ids = []
    for i, (feature, t) in enumerate(features_type.items()):
        if t == 'cat':
            print(i, feature)
            cat_ids.append(i)
    return cat_ids
cat_ids = temp()
cat_ids
# Out:
# 0 syndicator_id_hash
# 1 campaign_id_hash
# 4 target_item_taxonomy
# 5 placement_id_hash
# 9 publisher_id_hash
# 10 source_id_hash
# 11 source_item_type
# 12 browser_platform
# 13 os_family
# 14 country_code
# 15 region
# 18 gmt_offset
# 19 target_item_taxonomy_upper
# 24 local_day_part
# 25 user_type
# [0, 1, 4, 5, 9, 10, 11, 12, 13, 14, 15, 18, 19, 24, 25]

# %% [markdown]
# ## Running Vanilla CatBoost to check perfomance of new features

# %%
from catboost import CatBoostClassifier

model = CatBoostClassifier(iterations=1000,
                           task_type="GPU",
                           devices='0:1')
"""
0 user_id_hash
1 target_id_hash
2 syndicator_id_hash
3 campaign_id_hash
6 target_item_taxonomy
7 placement_id_hash
11 publisher_id_hash
12 source_id_hash
13 source_item_type
14 browser_platform
15 os_family
16 country_code
17 region
20 gmt_offset
"""

cat_features = [0, 1, 4, 5, 9, 10, 11, 12, 13, 14, 15, 18, 19, 24, 25]
model.fit(last_x_days_features, last_x_days_ground_truth, cat_features, verbose=True)
model.save_model(
    os.path.join('.', 'models', 'cboost-five-days-no-uid-tid-taxonomy-splitted-uctr-tctr-freq-many-ctr.cbm'),
    format="cbm",
    export_parameters=None,
    pool=None
)
# Out:
# Learning rate set to 0.020214
# 0:	learn: 0.6838871	total: 1.98s	remaining: 32m 55s
# 1:	learn: 0.6750777	total: 3.95s	remaining: 32m 50s
# 2:	learn: 0.6667699	total: 6.21s	remaining: 34m 22s
# 3:	learn: 0.6588244	total: 8.48s	remaining: 35m 11s
# 4:	learn: 0.6511539	total: 10.5s	remaining: 34m 39s
# 5:	learn: 0.6439338	total: 12.6s	remaining: 34m 42s
# 6:	learn: 0.6370113	total: 14.5s	remaining: 34m 22s
# 7:	learn: 0.6304445	total: 16.8s	remaining: 34m 45s
# 8:	learn: 0.6242112	total: 18.8s	remaining: 34m 28s
# 9:	learn: 0.6183053	total: 20.8s	remaining: 34m 20s
# 10:	learn: 0.6125305	total: 22.8s	remaining: 34m 8s
# 11:	learn: 0.6071363	total: 25.1s	remaining: 34m 23s
# 12:	learn: 0.6019534	total: 27s	remaining: 34m 12s
# 13:	learn: 0.5970472	total: 29.6s	remaining: 34m 43s
# 14:	learn: 0.5923089	total: 32.1s	remaining: 35m 10s
# 15:	learn: 0.5877969	total: 34.9s	remaining: 35m 43s
# 16:	learn: 0.5835776	total: 37s	remaining: 35m 39s
# 17:	learn: 0.5795404	total: 39.4s	remaining: 35m 51s
# 18:	learn: 0.5756660	total: 41.7s	remaining: 35m 53s
# 19:	learn: 0.5720621	total: 43.9s	remaining: 35m 52s
# 20:	learn: 0.5686476	total: 46.4s	remaining: 36m 3s
# 21:	learn: 0.5655423	total: 49.2s	remaining: 36m 28s
# 22:	learn: 0.5622849	total: 51.7s	remaining: 36m 34s
# 23:	learn: 0.5592369	total: 54.5s	remaining: 36m 56s
# 24:	learn: 0.5563387	total: 56.9s	remaining: 36m 59s
# 25:	learn: 0.5534421	total: 59.2s	remaining: 36m 55s
# 26:	learn: 0.5506664	total: 1m 1s	remaining: 36m 40s
# 27:	learn: 0.5481917	total: 1m 3s	remaining: 36m 51s
# 28:	learn: 0.5457381	total: 1m 6s	remaining: 36m 57s
# 29:	learn: 0.5434150	total: 1m 8s	remaining: 37m 3s
# 30:	learn: 0.5410776	total: 1m 11s	remaining: 37m 8s
# 31:	learn: 0.5388605	total: 1m 13s	remaining: 37m 5s
# 32:	learn: 0.5367920	total: 1m 15s	remaining: 36m 59s
# 33:	learn: 0.5348345	total: 1m 18s	remaining: 37m 4s
# 34:	learn: 0.5328758	total: 1m 20s	remaining: 36m 57s
# 35:	learn: 0.5312355	total: 1m 23s	remaining: 37m 19s
# 36:	learn: 0.5293785	total: 1m 25s	remaining: 37m 11s
# 37:	learn: 0.5278319	total: 1m 28s	remaining: 37m 19s
# 38:	learn: 0.5261170	total: 1m 30s	remaining: 37m 16s
# 39:	learn: 0.5245793	total: 1m 33s	remaining: 37m 14s
# 40:	learn: 0.5230434	total: 1m 35s	remaining: 37m 10s
# 41:	learn: 0.5216491	total: 1m 38s	remaining: 37m 18s
# 42:	learn: 0.5202119	total: 1m 40s	remaining: 37m 22s
# 43:	learn: 0.5188326	total: 1m 43s	remaining: 37m 21s
# 44:	learn: 0.5175681	total: 1m 45s	remaining: 37m 27s
# 45:	learn: 0.5163503	total: 1m 48s	remaining: 37m 25s
# 46:	learn: 0.5151419	total: 1m 50s	remaining: 37m 22s
# 47:	learn: 0.5139754	total: 1m 52s	remaining: 37m 20s
# 48:	learn: 0.5127932	total: 1m 55s	remaining: 37m 25s
# 49:	learn: 0.5116874	total: 1m 58s	remaining: 37m 28s
# 50:	learn: 0.5106691	total: 2m	remaining: 37m 25s
# 51:	learn: 0.5097144	total: 2m 3s	remaining: 37m 22s
# 52:	learn: 0.5087811	total: 2m 5s	remaining: 37m 29s
# 53:	learn: 0.5077906	total: 2m 8s	remaining: 37m 32s
# 54:	learn: 0.5068744	total: 2m 11s	remaining: 37m 34s
# 55:	learn: 0.5060289	total: 2m 13s	remaining: 37m 38s
# 56:	learn: 0.5051888	total: 2m 16s	remaining: 37m 45s
# 57:	learn: 0.5043962	total: 2m 19s	remaining: 37m 46s
# 58:	learn: 0.5036239	total: 2m 22s	remaining: 37m 50s
# 59:	learn: 0.5028078	total: 2m 25s	remaining: 37m 56s
# 60:	learn: 0.5021305	total: 2m 28s	remaining: 38m 8s
# 61:	learn: 0.5014735	total: 2m 31s	remaining: 38m 12s
# 62:	learn: 0.5007426	total: 2m 34s	remaining: 38m 16s
# 63:	learn: 0.5001157	total: 2m 37s	remaining: 38m 17s
# 64:	learn: 0.4994790	total: 2m 39s	remaining: 38m 17s
# 65:	learn: 0.4988320	total: 2m 42s	remaining: 38m 18s
# 66:	learn: 0.4982249	total: 2m 44s	remaining: 38m 16s
# 67:	learn: 0.4976288	total: 2m 47s	remaining: 38m 12s
# 68:	learn: 0.4970994	total: 2m 49s	remaining: 38m 12s
# 69:	learn: 0.4965779	total: 2m 52s	remaining: 38m 16s
# 70:	learn: 0.4960763	total: 2m 55s	remaining: 38m 16s
# 71:	learn: 0.4955939	total: 2m 58s	remaining: 38m 21s
# 72:	learn: 0.4951251	total: 3m 1s	remaining: 38m 20s
# 73:	learn: 0.4946480	total: 3m 3s	remaining: 38m 16s
# 74:	learn: 0.4942161	total: 3m 6s	remaining: 38m 20s
# 75:	learn: 0.4937758	total: 3m 8s	remaining: 38m 13s
# 76:	learn: 0.4933420	total: 3m 11s	remaining: 38m 15s
# 77:	learn: 0.4929297	total: 3m 14s	remaining: 38m 14s
# 78:	learn: 0.4925420	total: 3m 17s	remaining: 38m 16s
# 79:	learn: 0.4921721	total: 3m 19s	remaining: 38m 9s
# 80:	learn: 0.4918445	total: 3m 22s	remaining: 38m 12s
# 81:	learn: 0.4914806	total: 3m 24s	remaining: 38m 14s
# 82:	learn: 0.4911310	total: 3m 27s	remaining: 38m 9s
# 83:	learn: 0.4907639	total: 3m 29s	remaining: 38m 5s
# 84:	learn: 0.4904333	total: 3m 32s	remaining: 38m 5s
# 85:	learn: 0.4901124	total: 3m 35s	remaining: 38m 5s
# 86:	learn: 0.4897984	total: 3m 37s	remaining: 38m 3s
# 87:	learn: 0.4894964	total: 3m 40s	remaining: 38m 2s
# 88:	learn: 0.4892132	total: 3m 42s	remaining: 37m 55s
# 89:	learn: 0.4888922	total: 3m 44s	remaining: 37m 51s
# 90:	learn: 0.4886188	total: 3m 47s	remaining: 37m 51s
# 91:	learn: 0.4883225	total: 3m 49s	remaining: 37m 47s
# 92:	learn: 0.4880449	total: 3m 52s	remaining: 37m 44s
# 93:	learn: 0.4877976	total: 3m 54s	remaining: 37m 42s
# 94:	learn: 0.4875249	total: 3m 56s	remaining: 37m 37s
# 95:	learn: 0.4872892	total: 3m 59s	remaining: 37m 32s
# 96:	learn: 0.4870117	total: 4m 1s	remaining: 37m 30s
# 97:	learn: 0.4867782	total: 4m 4s	remaining: 37m 27s
# 98:	learn: 0.4865649	total: 4m 6s	remaining: 37m 25s
# 99:	learn: 0.4863584	total: 4m 9s	remaining: 37m 23s
# 100:	learn: 0.4861608	total: 4m 11s	remaining: 37m 17s
# 101:	learn: 0.4859454	total: 4m 13s	remaining: 37m 11s
# 102:	learn: 0.4857127	total: 4m 15s	remaining: 37m 7s
# 103:	learn: 0.4855395	total: 4m 18s	remaining: 37m 6s
# 104:	learn: 0.4853461	total: 4m 20s	remaining: 37m 3s
# 105:	learn: 0.4851704	total: 4m 23s	remaining: 36m 58s
# 106:	learn: 0.4850129	total: 4m 25s	remaining: 36m 54s
# 107:	learn: 0.4848532	total: 4m 27s	remaining: 36m 48s
# 108:	learn: 0.4846882	total: 4m 29s	remaining: 36m 43s
# 109:	learn: 0.4844710	total: 4m 31s	remaining: 36m 38s
# 110:	learn: 0.4843204	total: 4m 33s	remaining: 36m 32s
# 111:	learn: 0.4841505	total: 4m 35s	remaining: 36m 28s
# 112:	learn: 0.4839657	total: 4m 38s	remaining: 36m 27s
# 113:	learn: 0.4838241	total: 4m 40s	remaining: 36m 21s
# 114:	learn: 0.4836486	total: 4m 42s	remaining: 36m 16s
# 115:	learn: 0.4835091	total: 4m 45s	remaining: 36m 13s
# 116:	learn: 0.4833674	total: 4m 47s	remaining: 36m 11s
# 117:	learn: 0.4832520	total: 4m 50s	remaining: 36m 8s
# 118:	learn: 0.4831283	total: 4m 52s	remaining: 36m 4s
# 119:	learn: 0.4829996	total: 4m 55s	remaining: 36m 4s
# 120:	learn: 0.4828770	total: 4m 57s	remaining: 35m 59s
# 121:	learn: 0.4827642	total: 4m 59s	remaining: 35m 58s
# 122:	learn: 0.4826261	total: 5m 2s	remaining: 35m 53s
# 123:	learn: 0.4824665	total: 5m 4s	remaining: 35m 54s
# 124:	learn: 0.4823512	total: 5m 7s	remaining: 35m 51s
# 125:	learn: 0.4822156	total: 5m 9s	remaining: 35m 48s
# 126:	learn: 0.4821006	total: 5m 12s	remaining: 35m 47s
# 127:	learn: 0.4820000	total: 5m 14s	remaining: 35m 45s
# 128:	learn: 0.4818822	total: 5m 17s	remaining: 35m 41s
# 129:	learn: 0.4817694	total: 5m 20s	remaining: 35m 41s
# 130:	learn: 0.4816717	total: 5m 22s	remaining: 35m 40s
# 131:	learn: 0.4815842	total: 5m 25s	remaining: 35m 38s
# 132:	learn: 0.4814883	total: 5m 27s	remaining: 35m 36s
# 133:	learn: 0.4813858	total: 5m 30s	remaining: 35m 34s
# 134:	learn: 0.4813121	total: 5m 33s	remaining: 35m 34s
# 135:	learn: 0.4812331	total: 5m 35s	remaining: 35m 30s
# 136:	learn: 0.4811373	total: 5m 38s	remaining: 35m 29s
# 137:	learn: 0.4810510	total: 5m 40s	remaining: 35m 27s
# 138:	learn: 0.4809365	total: 5m 43s	remaining: 35m 26s
# 139:	learn: 0.4808607	total: 5m 45s	remaining: 35m 24s
# 140:	learn: 0.4807674	total: 5m 48s	remaining: 35m 24s
# 141:	learn: 0.4806792	total: 5m 50s	remaining: 35m 18s
# 142:	learn: 0.4806083	total: 5m 52s	remaining: 35m 14s
# 143:	learn: 0.4805263	total: 5m 55s	remaining: 35m 11s
# 144:	learn: 0.4804520	total: 5m 57s	remaining: 35m 8s
# 145:	learn: 0.4803824	total: 5m 59s	remaining: 35m 3s
# 146:	learn: 0.4803035	total: 6m 2s	remaining: 35m 2s
# 147:	learn: 0.4802290	total: 6m 4s	remaining: 34m 59s
# 148:	learn: 0.4801518	total: 6m 7s	remaining: 34m 58s
# 149:	learn: 0.4800530	total: 6m 10s	remaining: 34m 57s
# 150:	learn: 0.4799788	total: 6m 12s	remaining: 34m 54s
# 151:	learn: 0.4799135	total: 6m 15s	remaining: 34m 53s
# 152:	learn: 0.4798409	total: 6m 17s	remaining: 34m 50s
# 153:	learn: 0.4797545	total: 6m 20s	remaining: 34m 49s
# 154:	learn: 0.4796933	total: 6m 22s	remaining: 34m 47s
# 155:	learn: 0.4796333	total: 6m 24s	remaining: 34m 42s
# 156:	learn: 0.4795702	total: 6m 27s	remaining: 34m 41s
# 157:	learn: 0.4794965	total: 6m 30s	remaining: 34m 40s
# 158:	learn: 0.4794374	total: 6m 32s	remaining: 34m 38s
# 159:	learn: 0.4793881	total: 6m 35s	remaining: 34m 36s
# 160:	learn: 0.4793143	total: 6m 38s	remaining: 34m 34s
# 161:	learn: 0.4792638	total: 6m 40s	remaining: 34m 30s
# 162:	learn: 0.4792100	total: 6m 42s	remaining: 34m 28s
# 163:	learn: 0.4791628	total: 6m 45s	remaining: 34m 24s
# 164:	learn: 0.4791013	total: 6m 47s	remaining: 34m 24s
# 165:	learn: 0.4790544	total: 6m 49s	remaining: 34m 19s
# 166:	learn: 0.4790158	total: 6m 52s	remaining: 34m 15s
# 167:	learn: 0.4789598	total: 6m 54s	remaining: 34m 13s
# 168:	learn: 0.4789046	total: 6m 56s	remaining: 34m 10s
# 169:	learn: 0.4788644	total: 6m 59s	remaining: 34m 7s
# 170:	learn: 0.4787948	total: 7m 2s	remaining: 34m 6s
# 171:	learn: 0.4787292	total: 7m 4s	remaining: 34m 5s
# 172:	learn: 0.4786790	total: 7m 6s	remaining: 34m
# 173:	learn: 0.4786272	total: 7m 8s	remaining: 33m 56s
# 174:	learn: 0.4785877	total: 7m 11s	remaining: 33m 54s
# 175:	learn: 0.4785250	total: 7m 14s	remaining: 33m 53s
# 176:	learn: 0.4784785	total: 7m 17s	remaining: 33m 52s
# 177:	learn: 0.4784380	total: 7m 19s	remaining: 33m 48s
# 178:	learn: 0.4783991	total: 7m 22s	remaining: 33m 47s
# 179:	learn: 0.4783642	total: 7m 24s	remaining: 33m 45s
# 180:	learn: 0.4783086	total: 7m 26s	remaining: 33m 42s
# 181:	learn: 0.4782697	total: 7m 29s	remaining: 33m 40s
# 182:	learn: 0.4782152	total: 7m 31s	remaining: 33m 36s
# 183:	learn: 0.4781804	total: 7m 34s	remaining: 33m 33s
# 184:	learn: 0.4781494	total: 7m 36s	remaining: 33m 32s
# 185:	learn: 0.4781008	total: 7m 38s	remaining: 33m 28s
# 186:	learn: 0.4780488	total: 7m 41s	remaining: 33m 26s
# 187:	learn: 0.4780205	total: 7m 43s	remaining: 33m 23s
# 188:	learn: 0.4779867	total: 7m 45s	remaining: 33m 18s
# 189:	learn: 0.4779497	total: 7m 47s	remaining: 33m 13s
# 190:	learn: 0.4779106	total: 7m 50s	remaining: 33m 11s
# 191:	learn: 0.4778775	total: 7m 52s	remaining: 33m 7s
# 192:	learn: 0.4778344	total: 7m 54s	remaining: 33m 5s
# 193:	learn: 0.4777852	total: 7m 57s	remaining: 33m 4s
# 194:	learn: 0.4777392	total: 8m	remaining: 33m 2s
# 195:	learn: 0.4776976	total: 8m 3s	remaining: 33m 1s
# 196:	learn: 0.4776448	total: 8m 4s	remaining: 32m 56s
# 197:	learn: 0.4776153	total: 8m 7s	remaining: 32m 52s
# 198:	learn: 0.4775718	total: 8m 9s	remaining: 32m 51s
# 199:	learn: 0.4775400	total: 8m 12s	remaining: 32m 49s
# 200:	learn: 0.4774953	total: 8m 15s	remaining: 32m 48s
# 201:	learn: 0.4774514	total: 8m 17s	remaining: 32m 44s
# 202:	learn: 0.4774088	total: 8m 19s	remaining: 32m 40s
# 203:	learn: 0.4773824	total: 8m 22s	remaining: 32m 39s
# 204:	learn: 0.4773556	total: 8m 24s	remaining: 32m 36s
# 205:	learn: 0.4773167	total: 8m 26s	remaining: 32m 33s
# 206:	learn: 0.4772944	total: 8m 29s	remaining: 32m 31s
# 207:	learn: 0.4772527	total: 8m 31s	remaining: 32m 29s
# 208:	learn: 0.4772274	total: 8m 34s	remaining: 32m 25s
# 209:	learn: 0.4772027	total: 8m 36s	remaining: 32m 23s
# 210:	learn: 0.4771760	total: 8m 38s	remaining: 32m 19s
# 211:	learn: 0.4771448	total: 8m 41s	remaining: 32m 19s
# 212:	learn: 0.4771160	total: 8m 44s	remaining: 32m 18s
# 213:	learn: 0.4770739	total: 8m 47s	remaining: 32m 16s
# 214:	learn: 0.4770390	total: 8m 49s	remaining: 32m 13s
# 215:	learn: 0.4769982	total: 8m 52s	remaining: 32m 12s
# 216:	learn: 0.4769683	total: 8m 55s	remaining: 32m 10s
# 217:	learn: 0.4769458	total: 8m 57s	remaining: 32m 8s
# 218:	learn: 0.4769128	total: 8m 59s	remaining: 32m 4s
# 219:	learn: 0.4768881	total: 9m 1s	remaining: 32m 1s
# 220:	learn: 0.4768640	total: 9m 4s	remaining: 31m 59s
# 221:	learn: 0.4768368	total: 9m 6s	remaining: 31m 56s
# 222:	learn: 0.4767953	total: 9m 9s	remaining: 31m 54s
# 223:	learn: 0.4767671	total: 9m 12s	remaining: 31m 52s
# 224:	learn: 0.4767299	total: 9m 14s	remaining: 31m 49s
# 225:	learn: 0.4767119	total: 9m 16s	remaining: 31m 46s
# 226:	learn: 0.4766891	total: 9m 19s	remaining: 31m 44s
# 227:	learn: 0.4766672	total: 9m 21s	remaining: 31m 40s
# 228:	learn: 0.4766416	total: 9m 24s	remaining: 31m 39s
# 229:	learn: 0.4766073	total: 9m 26s	remaining: 31m 35s
# 230:	learn: 0.4765720	total: 9m 28s	remaining: 31m 32s
# 231:	learn: 0.4765346	total: 9m 30s	remaining: 31m 29s
# 232:	learn: 0.4765006	total: 9m 32s	remaining: 31m 25s
# 233:	learn: 0.4764814	total: 9m 34s	remaining: 31m 21s
# 234:	learn: 0.4764414	total: 9m 37s	remaining: 31m 18s
# 235:	learn: 0.4764166	total: 9m 38s	remaining: 31m 13s
# 236:	learn: 0.4763823	total: 9m 40s	remaining: 31m 9s
# 237:	learn: 0.4763592	total: 9m 42s	remaining: 31m 6s
# 238:	learn: 0.4763369	total: 9m 44s	remaining: 31m 1s
# 239:	learn: 0.4762959	total: 9m 46s	remaining: 30m 58s
# 240:	learn: 0.4762654	total: 9m 48s	remaining: 30m 54s
# 241:	learn: 0.4762486	total: 9m 50s	remaining: 30m 50s
# 242:	learn: 0.4762172	total: 9m 52s	remaining: 30m 46s
# 243:	learn: 0.4761988	total: 9m 54s	remaining: 30m 43s
# 244:	learn: 0.4761725	total: 9m 57s	remaining: 30m 40s
# 245:	learn: 0.4761390	total: 9m 59s	remaining: 30m 37s
# 246:	learn: 0.4761067	total: 10m 1s	remaining: 30m 34s
# 247:	learn: 0.4760901	total: 10m 4s	remaining: 30m 32s
# 248:	learn: 0.4760703	total: 10m 6s	remaining: 30m 30s
# 249:	learn: 0.4760439	total: 10m 9s	remaining: 30m 28s
# 250:	learn: 0.4760199	total: 10m 11s	remaining: 30m 25s
# 251:	learn: 0.4759860	total: 10m 14s	remaining: 30m 23s
# 252:	learn: 0.4759638	total: 10m 16s	remaining: 30m 20s
# 253:	learn: 0.4759356	total: 10m 18s	remaining: 30m 17s
# 254:	learn: 0.4759079	total: 10m 20s	remaining: 30m 13s
# 255:	learn: 0.4758819	total: 10m 22s	remaining: 30m 10s
# 256:	learn: 0.4758504	total: 10m 25s	remaining: 30m 7s
# 257:	learn: 0.4758274	total: 10m 27s	remaining: 30m 5s
# 258:	learn: 0.4757984	total: 10m 29s	remaining: 30m 2s
# 259:	learn: 0.4757703	total: 10m 32s	remaining: 30m
# 260:	learn: 0.4757463	total: 10m 34s	remaining: 29m 56s
# 261:	learn: 0.4757155	total: 10m 36s	remaining: 29m 53s
# 262:	learn: 0.4756960	total: 10m 38s	remaining: 29m 50s
# 263:	learn: 0.4756821	total: 10m 40s	remaining: 29m 46s
# 264:	learn: 0.4756505	total: 10m 42s	remaining: 29m 43s
# 265:	learn: 0.4756230	total: 10m 44s	remaining: 29m 39s
# 266:	learn: 0.4755979	total: 10m 47s	remaining: 29m 36s
# 267:	learn: 0.4755713	total: 10m 49s	remaining: 29m 33s
# 268:	learn: 0.4755524	total: 10m 51s	remaining: 29m 30s
# 269:	learn: 0.4755366	total: 10m 53s	remaining: 29m 26s
# 270:	learn: 0.4755064	total: 10m 55s	remaining: 29m 22s
# 271:	learn: 0.4754872	total: 10m 57s	remaining: 29m 20s
# 272:	learn: 0.4754741	total: 11m	remaining: 29m 18s
# 273:	learn: 0.4754560	total: 11m 2s	remaining: 29m 16s
# 274:	learn: 0.4754276	total: 11m 5s	remaining: 29m 13s
# 275:	learn: 0.4754092	total: 11m 7s	remaining: 29m 10s
# 276:	learn: 0.4753942	total: 11m 9s	remaining: 29m 6s
# 277:	learn: 0.4753754	total: 11m 10s	remaining: 29m 2s
# 278:	learn: 0.4753447	total: 11m 12s	remaining: 28m 59s
# 279:	learn: 0.4753263	total: 11m 15s	remaining: 28m 56s
# 280:	learn: 0.4753009	total: 11m 17s	remaining: 28m 53s
# 281:	learn: 0.4752825	total: 11m 19s	remaining: 28m 50s
# 282:	learn: 0.4752651	total: 11m 21s	remaining: 28m 47s
# 283:	learn: 0.4752330	total: 11m 24s	remaining: 28m 45s
# 284:	learn: 0.4752098	total: 11m 26s	remaining: 28m 42s
# 285:	learn: 0.4751920	total: 11m 29s	remaining: 28m 40s
# 286:	learn: 0.4751714	total: 11m 30s	remaining: 28m 36s
# 287:	learn: 0.4751542	total: 11m 33s	remaining: 28m 34s
# 288:	learn: 0.4751358	total: 11m 35s	remaining: 28m 31s
# 289:	learn: 0.4751163	total: 11m 38s	remaining: 28m 29s
# 290:	learn: 0.4750900	total: 11m 39s	remaining: 28m 24s
# 291:	learn: 0.4750615	total: 11m 41s	remaining: 28m 20s
# 292:	learn: 0.4750374	total: 11m 43s	remaining: 28m 17s
# 293:	learn: 0.4750137	total: 11m 45s	remaining: 28m 14s
# 294:	learn: 0.4749905	total: 11m 47s	remaining: 28m 10s
# 295:	learn: 0.4749696	total: 11m 49s	remaining: 28m 7s
# 296:	learn: 0.4749567	total: 11m 52s	remaining: 28m 5s
# 297:	learn: 0.4749432	total: 11m 54s	remaining: 28m 3s
# 298:	learn: 0.4749235	total: 11m 57s	remaining: 28m 1s
# 299:	learn: 0.4749020	total: 11m 59s	remaining: 27m 58s
# 300:	learn: 0.4748795	total: 12m 1s	remaining: 27m 55s
# 301:	learn: 0.4748589	total: 12m 3s	remaining: 27m 53s
# 302:	learn: 0.4748420	total: 12m 6s	remaining: 27m 51s
# 303:	learn: 0.4748293	total: 12m 9s	remaining: 27m 49s
# 304:	learn: 0.4748047	total: 12m 10s	remaining: 27m 45s
# 305:	learn: 0.4747856	total: 12m 12s	remaining: 27m 41s
# 306:	learn: 0.4747612	total: 12m 15s	remaining: 27m 39s
# 307:	learn: 0.4747419	total: 12m 17s	remaining: 27m 36s
# 308:	learn: 0.4747169	total: 12m 19s	remaining: 27m 33s
# 309:	learn: 0.4746973	total: 12m 21s	remaining: 27m 30s
# 310:	learn: 0.4746799	total: 12m 23s	remaining: 27m 28s
# 311:	learn: 0.4746558	total: 12m 26s	remaining: 27m 25s
# 312:	learn: 0.4746447	total: 12m 27s	remaining: 27m 21s
# 313:	learn: 0.4746288	total: 12m 30s	remaining: 27m 19s
# 314:	learn: 0.4746177	total: 12m 32s	remaining: 27m 16s
# 315:	learn: 0.4745972	total: 12m 34s	remaining: 27m 13s
# 316:	learn: 0.4745761	total: 12m 37s	remaining: 27m 11s
# 317:	learn: 0.4745510	total: 12m 39s	remaining: 27m 7s
# 318:	learn: 0.4745260	total: 12m 41s	remaining: 27m 4s
# 319:	learn: 0.4745035	total: 12m 43s	remaining: 27m 1s
# 320:	learn: 0.4744816	total: 12m 45s	remaining: 26m 59s
# 321:	learn: 0.4744690	total: 12m 48s	remaining: 26m 57s
# 322:	learn: 0.4744414	total: 12m 50s	remaining: 26m 54s
# 323:	learn: 0.4744218	total: 12m 52s	remaining: 26m 51s
# 324:	learn: 0.4744099	total: 12m 54s	remaining: 26m 48s
# 325:	learn: 0.4743930	total: 12m 56s	remaining: 26m 46s
# 326:	learn: 0.4743758	total: 12m 58s	remaining: 26m 42s
# 327:	learn: 0.4743656	total: 13m 1s	remaining: 26m 40s
# 328:	learn: 0.4743440	total: 13m 2s	remaining: 26m 36s
# 329:	learn: 0.4743310	total: 13m 5s	remaining: 26m 34s
# 330:	learn: 0.4743135	total: 13m 7s	remaining: 26m 31s
# 331:	learn: 0.4742885	total: 13m 9s	remaining: 26m 28s
# 332:	learn: 0.4742760	total: 13m 10s	remaining: 26m 24s
# 333:	learn: 0.4742559	total: 13m 12s	remaining: 26m 20s
# 334:	learn: 0.4742341	total: 13m 15s	remaining: 26m 19s
# 335:	learn: 0.4742088	total: 13m 17s	remaining: 26m 16s
# 336:	learn: 0.4741989	total: 13m 20s	remaining: 26m 14s
# 337:	learn: 0.4741863	total: 13m 22s	remaining: 26m 11s
# 338:	learn: 0.4741699	total: 13m 24s	remaining: 26m 8s
# 339:	learn: 0.4741559	total: 13m 26s	remaining: 26m 5s
# 340:	learn: 0.4741375	total: 13m 28s	remaining: 26m 2s
# 341:	learn: 0.4741191	total: 13m 31s	remaining: 26m
# 342:	learn: 0.4741055	total: 13m 33s	remaining: 25m 57s
# 343:	learn: 0.4740958	total: 13m 35s	remaining: 25m 54s
# 344:	learn: 0.4740767	total: 13m 37s	remaining: 25m 51s
# 345:	learn: 0.4740571	total: 13m 39s	remaining: 25m 48s
# 346:	learn: 0.4740364	total: 13m 40s	remaining: 25m 44s
# 347:	learn: 0.4740169	total: 13m 42s	remaining: 25m 41s
# 348:	learn: 0.4739962	total: 13m 44s	remaining: 25m 37s
# 349:	learn: 0.4739755	total: 13m 46s	remaining: 25m 34s
# 350:	learn: 0.4739665	total: 13m 48s	remaining: 25m 31s
# 351:	learn: 0.4739455	total: 13m 50s	remaining: 25m 29s
# 352:	learn: 0.4739296	total: 13m 52s	remaining: 25m 26s
# 353:	learn: 0.4739194	total: 13m 54s	remaining: 25m 23s
# 354:	learn: 0.4739117	total: 13m 57s	remaining: 25m 21s
# 355:	learn: 0.4738963	total: 13m 59s	remaining: 25m 19s
# 356:	learn: 0.4738798	total: 14m 1s	remaining: 25m 16s
# 357:	learn: 0.4738617	total: 14m 4s	remaining: 25m 14s
# 358:	learn: 0.4738500	total: 14m 6s	remaining: 25m 11s
# 359:	learn: 0.4738254	total: 14m 9s	remaining: 25m 9s
# 360:	learn: 0.4738100	total: 14m 11s	remaining: 25m 7s
# 361:	learn: 0.4737934	total: 14m 13s	remaining: 25m 4s
# 362:	learn: 0.4737755	total: 14m 16s	remaining: 25m 2s
# 363:	learn: 0.4737627	total: 14m 18s	remaining: 24m 59s
# 364:	learn: 0.4737516	total: 14m 20s	remaining: 24m 56s
# 365:	learn: 0.4737377	total: 14m 22s	remaining: 24m 53s
# 366:	learn: 0.4737196	total: 14m 24s	remaining: 24m 51s
# 367:	learn: 0.4737064	total: 14m 26s	remaining: 24m 48s
# 368:	learn: 0.4736876	total: 14m 28s	remaining: 24m 45s
# 369:	learn: 0.4736783	total: 14m 31s	remaining: 24m 43s
# 370:	learn: 0.4736663	total: 14m 33s	remaining: 24m 40s
# 371:	learn: 0.4736581	total: 14m 35s	remaining: 24m 38s
# 372:	learn: 0.4736466	total: 14m 38s	remaining: 24m 36s
# 373:	learn: 0.4736292	total: 14m 40s	remaining: 24m 34s
# 374:	learn: 0.4736090	total: 14m 42s	remaining: 24m 30s
# 375:	learn: 0.4735975	total: 14m 44s	remaining: 24m 28s
# 376:	learn: 0.4735857	total: 14m 47s	remaining: 24m 26s
# 377:	learn: 0.4735714	total: 14m 49s	remaining: 24m 23s
# 378:	learn: 0.4735587	total: 14m 52s	remaining: 24m 22s
# 379:	learn: 0.4735430	total: 14m 54s	remaining: 24m 19s
# 380:	learn: 0.4735306	total: 14m 56s	remaining: 24m 16s
# 381:	learn: 0.4735181	total: 14m 58s	remaining: 24m 13s
# 382:	learn: 0.4735005	total: 15m	remaining: 24m 10s
# 383:	learn: 0.4734927	total: 15m 2s	remaining: 24m 7s
# 384:	learn: 0.4734848	total: 15m 4s	remaining: 24m 5s
# 385:	learn: 0.4734740	total: 15m 7s	remaining: 24m 3s
# 386:	learn: 0.4734555	total: 15m 9s	remaining: 24m
# 387:	learn: 0.4734418	total: 15m 12s	remaining: 23m 58s
# 388:	learn: 0.4734307	total: 15m 14s	remaining: 23m 56s
# 389:	learn: 0.4734228	total: 15m 16s	remaining: 23m 53s
# 390:	learn: 0.4734117	total: 15m 18s	remaining: 23m 50s
# 391:	learn: 0.4734054	total: 15m 20s	remaining: 23m 47s
# 392:	learn: 0.4733929	total: 15m 23s	remaining: 23m 45s
# 393:	learn: 0.4733823	total: 15m 25s	remaining: 23m 43s
# 394:	learn: 0.4733682	total: 15m 28s	remaining: 23m 41s
# 395:	learn: 0.4733601	total: 15m 30s	remaining: 23m 39s
# 396:	learn: 0.4733483	total: 15m 32s	remaining: 23m 35s
# 397:	learn: 0.4733389	total: 15m 34s	remaining: 23m 33s
# 398:	learn: 0.4733312	total: 15m 36s	remaining: 23m 30s
# 399:	learn: 0.4733144	total: 15m 38s	remaining: 23m 27s
# 400:	learn: 0.4733043	total: 15m 41s	remaining: 23m 25s
# 401:	learn: 0.4732916	total: 15m 42s	remaining: 23m 22s
# 402:	learn: 0.4732765	total: 15m 45s	remaining: 23m 20s
# 403:	learn: 0.4732612	total: 15m 47s	remaining: 23m 17s
# 404:	learn: 0.4732494	total: 15m 49s	remaining: 23m 14s
# 405:	learn: 0.4732334	total: 15m 50s	remaining: 23m 11s
# 406:	learn: 0.4732190	total: 15m 52s	remaining: 23m 8s
# 407:	learn: 0.4732018	total: 15m 55s	remaining: 23m 5s
# 408:	learn: 0.4731908	total: 15m 57s	remaining: 23m 3s
# 409:	learn: 0.4731714	total: 15m 59s	remaining: 23m
# 410:	learn: 0.4731668	total: 16m 1s	remaining: 22m 58s
# 411:	learn: 0.4731467	total: 16m 3s	remaining: 22m 55s
# 412:	learn: 0.4731394	total: 16m 5s	remaining: 22m 52s
# 413:	learn: 0.4731258	total: 16m 8s	remaining: 22m 50s
# 414:	learn: 0.4731129	total: 16m 10s	remaining: 22m 48s
# 415:	learn: 0.4731007	total: 16m 12s	remaining: 22m 45s
# 416:	learn: 0.4730950	total: 16m 15s	remaining: 22m 43s
# 417:	learn: 0.4730852	total: 16m 17s	remaining: 22m 41s
# 418:	learn: 0.4730735	total: 16m 19s	remaining: 22m 38s
# 419:	learn: 0.4730614	total: 16m 22s	remaining: 22m 36s
# 420:	learn: 0.4730519	total: 16m 24s	remaining: 22m 34s
# 421:	learn: 0.4730384	total: 16m 26s	remaining: 22m 30s
# 422:	learn: 0.4730254	total: 16m 28s	remaining: 22m 27s
# 423:	learn: 0.4730140	total: 16m 30s	remaining: 22m 25s
# 424:	learn: 0.4729941	total: 16m 33s	remaining: 22m 23s
# 425:	learn: 0.4729835	total: 16m 34s	remaining: 22m 20s
# 426:	learn: 0.4729695	total: 16m 37s	remaining: 22m 18s
# 427:	learn: 0.4729631	total: 16m 39s	remaining: 22m 15s
# 428:	learn: 0.4729464	total: 16m 41s	remaining: 22m 12s
# 429:	learn: 0.4729344	total: 16m 43s	remaining: 22m 10s
# 430:	learn: 0.4729276	total: 16m 45s	remaining: 22m 7s
# 431:	learn: 0.4729104	total: 16m 47s	remaining: 22m 4s
# 432:	learn: 0.4728975	total: 16m 49s	remaining: 22m 1s
# 433:	learn: 0.4728898	total: 16m 51s	remaining: 21m 59s
# 434:	learn: 0.4728828	total: 16m 54s	remaining: 21m 57s
# 435:	learn: 0.4728686	total: 16m 56s	remaining: 21m 55s
# 436:	learn: 0.4728620	total: 16m 58s	remaining: 21m 52s
# 437:	learn: 0.4728526	total: 17m	remaining: 21m 49s
# 438:	learn: 0.4728400	total: 17m 2s	remaining: 21m 46s
# 439:	learn: 0.4728292	total: 17m 3s	remaining: 21m 43s
# 440:	learn: 0.4728218	total: 17m 6s	remaining: 21m 41s
# 441:	learn: 0.4728120	total: 17m 8s	remaining: 21m 38s
# 442:	learn: 0.4728019	total: 17m 10s	remaining: 21m 36s
# 443:	learn: 0.4727925	total: 17m 13s	remaining: 21m 33s
# 444:	learn: 0.4727817	total: 17m 15s	remaining: 21m 31s
# 445:	learn: 0.4727672	total: 17m 18s	remaining: 21m 29s
# 446:	learn: 0.4727565	total: 17m 20s	remaining: 21m 27s
# 447:	learn: 0.4727477	total: 17m 22s	remaining: 21m 24s
# 448:	learn: 0.4727396	total: 17m 24s	remaining: 21m 21s
# 449:	learn: 0.4727315	total: 17m 26s	remaining: 21m 19s
# 450:	learn: 0.4727197	total: 17m 28s	remaining: 21m 16s
# 451:	learn: 0.4727019	total: 17m 30s	remaining: 21m 14s
# 452:	learn: 0.4726927	total: 17m 33s	remaining: 21m 11s
# 453:	learn: 0.4726786	total: 17m 35s	remaining: 21m 9s
# 454:	learn: 0.4726711	total: 17m 37s	remaining: 21m 6s
# 455:	learn: 0.4726616	total: 17m 40s	remaining: 21m 4s
# 456:	learn: 0.4726508	total: 17m 42s	remaining: 21m 2s
# 457:	learn: 0.4726441	total: 17m 44s	remaining: 20m 59s
# 458:	learn: 0.4726348	total: 17m 46s	remaining: 20m 57s
# 459:	learn: 0.4726257	total: 17m 49s	remaining: 20m 55s
# 460:	learn: 0.4726078	total: 17m 51s	remaining: 20m 52s
# 461:	learn: 0.4725988	total: 17m 53s	remaining: 20m 50s
# 462:	learn: 0.4725934	total: 17m 56s	remaining: 20m 48s
# 463:	learn: 0.4725842	total: 17m 57s	remaining: 20m 45s
# 464:	learn: 0.4725776	total: 18m	remaining: 20m 43s
# 465:	learn: 0.4725715	total: 18m 2s	remaining: 20m 40s
# 466:	learn: 0.4725657	total: 18m 4s	remaining: 20m 37s
# 467:	learn: 0.4725537	total: 18m 6s	remaining: 20m 35s
# 468:	learn: 0.4725470	total: 18m 8s	remaining: 20m 32s
# 469:	learn: 0.4725332	total: 18m 10s	remaining: 20m 29s
# 470:	learn: 0.4725260	total: 18m 12s	remaining: 20m 27s
# 471:	learn: 0.4725136	total: 18m 15s	remaining: 20m 25s
# 472:	learn: 0.4725026	total: 18m 17s	remaining: 20m 23s
# 473:	learn: 0.4724906	total: 18m 20s	remaining: 20m 20s
# 474:	learn: 0.4724840	total: 18m 22s	remaining: 20m 18s
# 475:	learn: 0.4724747	total: 18m 23s	remaining: 20m 15s
# 476:	learn: 0.4724698	total: 18m 25s	remaining: 20m 12s
# 477:	learn: 0.4724626	total: 18m 27s	remaining: 20m 9s
# 478:	learn: 0.4724497	total: 18m 29s	remaining: 20m 6s
# 479:	learn: 0.4724420	total: 18m 31s	remaining: 20m 4s
# 480:	learn: 0.4724341	total: 18m 33s	remaining: 20m 1s
# 481:	learn: 0.4724269	total: 18m 36s	remaining: 19m 59s
# 482:	learn: 0.4724205	total: 18m 38s	remaining: 19m 57s
# 483:	learn: 0.4724153	total: 18m 40s	remaining: 19m 54s
# 484:	learn: 0.4724050	total: 18m 43s	remaining: 19m 52s
# 485:	learn: 0.4723980	total: 18m 45s	remaining: 19m 50s
# 486:	learn: 0.4723850	total: 18m 48s	remaining: 19m 48s
# 487:	learn: 0.4723783	total: 18m 50s	remaining: 19m 46s
# 488:	learn: 0.4723659	total: 18m 52s	remaining: 19m 43s
# 489:	learn: 0.4723586	total: 18m 54s	remaining: 19m 41s
# 490:	learn: 0.4723492	total: 18m 56s	remaining: 19m 38s
# 491:	learn: 0.4723367	total: 18m 58s	remaining: 19m 35s
# 492:	learn: 0.4723294	total: 19m	remaining: 19m 33s
# 493:	learn: 0.4723257	total: 19m 2s	remaining: 19m 30s
# 494:	learn: 0.4723154	total: 19m 4s	remaining: 19m 27s
# 495:	learn: 0.4723065	total: 19m 5s	remaining: 19m 24s
# 496:	learn: 0.4722971	total: 19m 7s	remaining: 19m 21s
# 497:	learn: 0.4722883	total: 19m 9s	remaining: 19m 19s
# 498:	learn: 0.4722832	total: 19m 11s	remaining: 19m 16s
# 499:	learn: 0.4722772	total: 19m 14s	remaining: 19m 14s
# 500:	learn: 0.4722712	total: 19m 16s	remaining: 19m 11s
# 501:	learn: 0.4722624	total: 19m 19s	remaining: 19m 9s
# 502:	learn: 0.4722500	total: 19m 20s	remaining: 19m 6s
# 503:	learn: 0.4722428	total: 19m 22s	remaining: 19m 4s
# 504:	learn: 0.4722368	total: 19m 25s	remaining: 19m 1s
# 505:	learn: 0.4722254	total: 19m 26s	remaining: 18m 59s
# 506:	learn: 0.4722209	total: 19m 28s	remaining: 18m 56s
# 507:	learn: 0.4722138	total: 19m 30s	remaining: 18m 53s
# 508:	learn: 0.4722072	total: 19m 32s	remaining: 18m 51s
# 509:	learn: 0.4721959	total: 19m 35s	remaining: 18m 48s
# 510:	learn: 0.4721855	total: 19m 37s	remaining: 18m 46s
# 511:	learn: 0.4721809	total: 19m 40s	remaining: 18m 44s
# 512:	learn: 0.4721701	total: 19m 42s	remaining: 18m 42s
# 513:	learn: 0.4721523	total: 19m 43s	remaining: 18m 39s
# 514:	learn: 0.4721347	total: 19m 45s	remaining: 18m 36s
# 515:	learn: 0.4721261	total: 19m 47s	remaining: 18m 34s
# 516:	learn: 0.4721168	total: 19m 50s	remaining: 18m 31s
# 517:	learn: 0.4721104	total: 19m 52s	remaining: 18m 29s
# 518:	learn: 0.4720961	total: 19m 54s	remaining: 18m 26s
# 519:	learn: 0.4720906	total: 19m 56s	remaining: 18m 24s
# 520:	learn: 0.4720822	total: 19m 58s	remaining: 18m 22s
# 521:	learn: 0.4720764	total: 20m	remaining: 18m 19s
# 522:	learn: 0.4720686	total: 20m 3s	remaining: 18m 17s
# 523:	learn: 0.4720651	total: 20m 5s	remaining: 18m 15s
# 524:	learn: 0.4720572	total: 20m 7s	remaining: 18m 12s
# 525:	learn: 0.4720465	total: 20m 9s	remaining: 18m 9s
# 526:	learn: 0.4720398	total: 20m 11s	remaining: 18m 7s
# 527:	learn: 0.4720332	total: 20m 13s	remaining: 18m 5s
# 528:	learn: 0.4720223	total: 20m 16s	remaining: 18m 2s
# 529:	learn: 0.4720127	total: 20m 17s	remaining: 17m 59s
# 530:	learn: 0.4720019	total: 20m 20s	remaining: 17m 57s
# 531:	learn: 0.4719926	total: 20m 22s	remaining: 17m 55s
# 532:	learn: 0.4719765	total: 20m 24s	remaining: 17m 53s
# 533:	learn: 0.4719632	total: 20m 26s	remaining: 17m 50s
# 534:	learn: 0.4719578	total: 20m 29s	remaining: 17m 48s
# 535:	learn: 0.4719515	total: 20m 32s	remaining: 17m 46s
# 536:	learn: 0.4719439	total: 20m 34s	remaining: 17m 44s
# 537:	learn: 0.4719339	total: 20m 36s	remaining: 17m 42s
# 538:	learn: 0.4719268	total: 20m 39s	remaining: 17m 39s
# 539:	learn: 0.4719230	total: 20m 41s	remaining: 17m 37s
# 540:	learn: 0.4719169	total: 20m 43s	remaining: 17m 34s
# 541:	learn: 0.4719094	total: 20m 46s	remaining: 17m 32s
# 542:	learn: 0.4719049	total: 20m 48s	remaining: 17m 30s
# 543:	learn: 0.4719005	total: 20m 50s	remaining: 17m 27s
# 544:	learn: 0.4718894	total: 20m 52s	remaining: 17m 25s
# 545:	learn: 0.4718830	total: 20m 54s	remaining: 17m 23s
# 546:	learn: 0.4718749	total: 20m 57s	remaining: 17m 21s
# 547:	learn: 0.4718669	total: 20m 58s	remaining: 17m 18s
# 548:	learn: 0.4718571	total: 21m 1s	remaining: 17m 16s
# 549:	learn: 0.4718479	total: 21m 3s	remaining: 17m 13s
# 550:	learn: 0.4718412	total: 21m 5s	remaining: 17m 11s
# 551:	learn: 0.4718334	total: 21m 7s	remaining: 17m 8s
# 552:	learn: 0.4718290	total: 21m 10s	remaining: 17m 6s
# 553:	learn: 0.4718214	total: 21m 12s	remaining: 17m 4s
# 554:	learn: 0.4718164	total: 21m 15s	remaining: 17m 2s
# 555:	learn: 0.4718123	total: 21m 17s	remaining: 17m
# 556:	learn: 0.4718018	total: 21m 19s	remaining: 16m 57s
# 557:	learn: 0.4717952	total: 21m 21s	remaining: 16m 54s
# 558:	learn: 0.4717917	total: 21m 23s	remaining: 16m 52s
# 559:	learn: 0.4717871	total: 21m 25s	remaining: 16m 50s
# 560:	learn: 0.4717809	total: 21m 27s	remaining: 16m 47s
# 561:	learn: 0.4717757	total: 21m 30s	remaining: 16m 45s
# 562:	learn: 0.4717616	total: 21m 32s	remaining: 16m 43s
# 563:	learn: 0.4717555	total: 21m 34s	remaining: 16m 41s
# 564:	learn: 0.4717432	total: 21m 36s	remaining: 16m 38s
# 565:	learn: 0.4717349	total: 21m 38s	remaining: 16m 35s
# 566:	learn: 0.4717236	total: 21m 40s	remaining: 16m 33s
# 567:	learn: 0.4717194	total: 21m 42s	remaining: 16m 30s
# 568:	learn: 0.4717105	total: 21m 44s	remaining: 16m 28s
# 569:	learn: 0.4716995	total: 21m 46s	remaining: 16m 25s
# 570:	learn: 0.4716932	total: 21m 49s	remaining: 16m 23s
# 571:	learn: 0.4716862	total: 21m 50s	remaining: 16m 20s
# 572:	learn: 0.4716744	total: 21m 52s	remaining: 16m 18s
# 573:	learn: 0.4716648	total: 21m 54s	remaining: 16m 15s
# 574:	learn: 0.4716584	total: 21m 56s	remaining: 16m 13s
# 575:	learn: 0.4716528	total: 21m 58s	remaining: 16m 10s
# 576:	learn: 0.4716505	total: 22m	remaining: 16m 8s
# 577:	learn: 0.4716437	total: 22m 2s	remaining: 16m 5s
# 578:	learn: 0.4716359	total: 22m 4s	remaining: 16m 3s
# 579:	learn: 0.4716292	total: 22m 6s	remaining: 16m
# 580:	learn: 0.4716229	total: 22m 8s	remaining: 15m 58s
# 581:	learn: 0.4716166	total: 22m 10s	remaining: 15m 55s
# 582:	learn: 0.4716107	total: 22m 12s	remaining: 15m 53s
# 583:	learn: 0.4716057	total: 22m 14s	remaining: 15m 50s
# 584:	learn: 0.4716001	total: 22m 17s	remaining: 15m 48s
# 585:	learn: 0.4715958	total: 22m 19s	remaining: 15m 46s
# 586:	learn: 0.4715857	total: 22m 21s	remaining: 15m 43s
# 587:	learn: 0.4715772	total: 22m 23s	remaining: 15m 41s
# 588:	learn: 0.4715717	total: 22m 25s	remaining: 15m 38s
# 589:	learn: 0.4715684	total: 22m 27s	remaining: 15m 36s
# 590:	learn: 0.4715622	total: 22m 29s	remaining: 15m 33s
# 591:	learn: 0.4715465	total: 22m 31s	remaining: 15m 31s
# 592:	learn: 0.4715422	total: 22m 33s	remaining: 15m 29s
# 593:	learn: 0.4715358	total: 22m 35s	remaining: 15m 26s
# 594:	learn: 0.4715290	total: 22m 37s	remaining: 15m 24s
# 595:	learn: 0.4715187	total: 22m 39s	remaining: 15m 21s
# 596:	learn: 0.4715130	total: 22m 41s	remaining: 15m 19s
# 597:	learn: 0.4715082	total: 22m 43s	remaining: 15m 16s
# 598:	learn: 0.4715028	total: 22m 46s	remaining: 15m 14s
# 599:	learn: 0.4714962	total: 22m 48s	remaining: 15m 12s
# 600:	learn: 0.4714899	total: 22m 50s	remaining: 15m 10s
# 601:	learn: 0.4714867	total: 22m 52s	remaining: 15m 7s
# 602:	learn: 0.4714822	total: 22m 54s	remaining: 15m 4s
# 603:	learn: 0.4714778	total: 22m 56s	remaining: 15m 2s
# 604:	learn: 0.4714714	total: 22m 59s	remaining: 15m
# 605:	learn: 0.4714635	total: 23m 1s	remaining: 14m 58s
# 606:	learn: 0.4714565	total: 23m 3s	remaining: 14m 55s
# 607:	learn: 0.4714473	total: 23m 5s	remaining: 14m 53s
# 608:	learn: 0.4714436	total: 23m 7s	remaining: 14m 50s
# 609:	learn: 0.4714367	total: 23m 9s	remaining: 14m 48s
# 610:	learn: 0.4714305	total: 23m 11s	remaining: 14m 46s
# 611:	learn: 0.4714214	total: 23m 14s	remaining: 14m 43s
# 612:	learn: 0.4714176	total: 23m 16s	remaining: 14m 41s
# 613:	learn: 0.4714132	total: 23m 18s	remaining: 14m 39s
# 614:	learn: 0.4714027	total: 23m 20s	remaining: 14m 36s
# 615:	learn: 0.4713954	total: 23m 22s	remaining: 14m 34s
# 616:	learn: 0.4713892	total: 23m 24s	remaining: 14m 31s
# 617:	learn: 0.4713852	total: 23m 26s	remaining: 14m 29s
# 618:	learn: 0.4713808	total: 23m 28s	remaining: 14m 27s
# 619:	learn: 0.4713745	total: 23m 30s	remaining: 14m 24s
# 620:	learn: 0.4713706	total: 23m 33s	remaining: 14m 22s
# 621:	learn: 0.4713640	total: 23m 34s	remaining: 14m 19s
# 622:	learn: 0.4713577	total: 23m 37s	remaining: 14m 17s
# 623:	learn: 0.4713537	total: 23m 39s	remaining: 14m 15s
# 624:	learn: 0.4713484	total: 23m 41s	remaining: 14m 13s
# 625:	learn: 0.4713406	total: 23m 43s	remaining: 14m 10s
# 626:	learn: 0.4713358	total: 23m 45s	remaining: 14m 8s
# 627:	learn: 0.4713277	total: 23m 47s	remaining: 14m 5s
# 628:	learn: 0.4713214	total: 23m 49s	remaining: 14m 3s
# 629:	learn: 0.4713182	total: 23m 51s	remaining: 14m
# 630:	learn: 0.4713125	total: 23m 52s	remaining: 13m 57s
# 631:	learn: 0.4713080	total: 23m 55s	remaining: 13m 55s
# 632:	learn: 0.4713016	total: 23m 58s	remaining: 13m 53s
# 633:	learn: 0.4712959	total: 24m	remaining: 13m 51s
# 634:	learn: 0.4712891	total: 24m 2s	remaining: 13m 49s
# 635:	learn: 0.4712804	total: 24m 5s	remaining: 13m 47s
# 636:	learn: 0.4712747	total: 24m 7s	remaining: 13m 45s
# 637:	learn: 0.4712685	total: 24m 10s	remaining: 13m 43s
# 638:	learn: 0.4712620	total: 24m 12s	remaining: 13m 40s
# 639:	learn: 0.4712572	total: 24m 14s	remaining: 13m 38s
# 640:	learn: 0.4712509	total: 24m 17s	remaining: 13m 36s
# 641:	learn: 0.4712430	total: 24m 19s	remaining: 13m 33s
# 642:	learn: 0.4712370	total: 24m 21s	remaining: 13m 31s
# 643:	learn: 0.4712337	total: 24m 23s	remaining: 13m 29s
# 644:	learn: 0.4712253	total: 24m 25s	remaining: 13m 26s
# 645:	learn: 0.4712195	total: 24m 27s	remaining: 13m 24s
# 646:	learn: 0.4712097	total: 24m 29s	remaining: 13m 21s
# 647:	learn: 0.4712056	total: 24m 32s	remaining: 13m 19s
# 648:	learn: 0.4711990	total: 24m 33s	remaining: 13m 17s
# 649:	learn: 0.4711913	total: 24m 36s	remaining: 13m 15s
# 650:	learn: 0.4711854	total: 24m 38s	remaining: 13m 12s
# 651:	learn: 0.4711790	total: 24m 40s	remaining: 13m 10s
# 652:	learn: 0.4711748	total: 24m 42s	remaining: 13m 7s
# 653:	learn: 0.4711687	total: 24m 44s	remaining: 13m 5s
# 654:	learn: 0.4711637	total: 24m 47s	remaining: 13m 3s
# 655:	learn: 0.4711597	total: 24m 49s	remaining: 13m 1s
# 656:	learn: 0.4711541	total: 24m 51s	remaining: 12m 58s
# 657:	learn: 0.4711465	total: 24m 53s	remaining: 12m 56s
# 658:	learn: 0.4711418	total: 24m 55s	remaining: 12m 54s
# 659:	learn: 0.4711347	total: 24m 58s	remaining: 12m 51s
# 660:	learn: 0.4711306	total: 25m	remaining: 12m 49s
# 661:	learn: 0.4711241	total: 25m 2s	remaining: 12m 47s
# 662:	learn: 0.4711192	total: 25m 5s	remaining: 12m 45s
# 663:	learn: 0.4711113	total: 25m 7s	remaining: 12m 42s
# 664:	learn: 0.4711060	total: 25m 10s	remaining: 12m 40s
# 665:	learn: 0.4711013	total: 25m 12s	remaining: 12m 38s
# 666:	learn: 0.4710945	total: 25m 15s	remaining: 12m 36s
# 667:	learn: 0.4710915	total: 25m 17s	remaining: 12m 34s
# 668:	learn: 0.4710852	total: 25m 19s	remaining: 12m 31s
# 669:	learn: 0.4710787	total: 25m 22s	remaining: 12m 29s
# 670:	learn: 0.4710746	total: 25m 24s	remaining: 12m 27s
# 671:	learn: 0.4710712	total: 25m 26s	remaining: 12m 24s
# 672:	learn: 0.4710637	total: 25m 27s	remaining: 12m 22s
# 673:	learn: 0.4710598	total: 25m 30s	remaining: 12m 20s
# 674:	learn: 0.4710558	total: 25m 32s	remaining: 12m 17s
# 675:	learn: 0.4710494	total: 25m 34s	remaining: 12m 15s
# 676:	learn: 0.4710447	total: 25m 36s	remaining: 12m 13s
# 677:	learn: 0.4710420	total: 25m 39s	remaining: 12m 10s
# 678:	learn: 0.4710384	total: 25m 41s	remaining: 12m 8s
# 679:	learn: 0.4710338	total: 25m 43s	remaining: 12m 6s
# 680:	learn: 0.4710298	total: 25m 46s	remaining: 12m 4s
# 681:	learn: 0.4710250	total: 25m 48s	remaining: 12m 2s
# 682:	learn: 0.4710156	total: 25m 50s	remaining: 11m 59s
# 683:	learn: 0.4710089	total: 25m 52s	remaining: 11m 57s
# 684:	learn: 0.4710026	total: 25m 54s	remaining: 11m 55s
# 685:	learn: 0.4709985	total: 25m 57s	remaining: 11m 52s
# 686:	learn: 0.4709917	total: 25m 59s	remaining: 11m 50s
# 687:	learn: 0.4709879	total: 26m 1s	remaining: 11m 48s
# 688:	learn: 0.4709827	total: 26m 3s	remaining: 11m 45s
# 689:	learn: 0.4709746	total: 26m 5s	remaining: 11m 43s
# 690:	learn: 0.4709703	total: 26m 7s	remaining: 11m 41s
# 691:	learn: 0.4709633	total: 26m 9s	remaining: 11m 38s
# 692:	learn: 0.4709536	total: 26m 11s	remaining: 11m 36s
# 693:	learn: 0.4709465	total: 26m 13s	remaining: 11m 33s
# 694:	learn: 0.4709405	total: 26m 15s	remaining: 11m 31s
# 695:	learn: 0.4709365	total: 26m 17s	remaining: 11m 29s
# 696:	learn: 0.4709309	total: 26m 19s	remaining: 11m 26s
# 697:	learn: 0.4709243	total: 26m 21s	remaining: 11m 24s
# 698:	learn: 0.4709151	total: 26m 24s	remaining: 11m 22s
# 699:	learn: 0.4709093	total: 26m 26s	remaining: 11m 19s
# 700:	learn: 0.4709033	total: 26m 28s	remaining: 11m 17s
# 701:	learn: 0.4709011	total: 26m 30s	remaining: 11m 14s
# 702:	learn: 0.4708928	total: 26m 31s	remaining: 11m 12s
# 703:	learn: 0.4708863	total: 26m 34s	remaining: 11m 10s
# 704:	learn: 0.4708824	total: 26m 35s	remaining: 11m 7s
# 705:	learn: 0.4708769	total: 26m 37s	remaining: 11m 5s
# 706:	learn: 0.4708721	total: 26m 40s	remaining: 11m 3s
# 707:	learn: 0.4708681	total: 26m 41s	remaining: 11m
# 708:	learn: 0.4708640	total: 26m 43s	remaining: 10m 58s
# 709:	learn: 0.4708599	total: 26m 45s	remaining: 10m 55s
# 710:	learn: 0.4708563	total: 26m 47s	remaining: 10m 53s
# 711:	learn: 0.4708530	total: 26m 50s	remaining: 10m 51s
# 712:	learn: 0.4708482	total: 26m 53s	remaining: 10m 49s
# 713:	learn: 0.4708434	total: 26m 55s	remaining: 10m 47s
# 714:	learn: 0.4708360	total: 26m 57s	remaining: 10m 44s
# 715:	learn: 0.4708323	total: 27m	remaining: 10m 42s
# 716:	learn: 0.4708279	total: 27m 2s	remaining: 10m 40s
# 717:	learn: 0.4708228	total: 27m 4s	remaining: 10m 38s
# 718:	learn: 0.4708184	total: 27m 6s	remaining: 10m 35s
# 719:	learn: 0.4708100	total: 27m 8s	remaining: 10m 33s
# 720:	learn: 0.4708076	total: 27m 10s	remaining: 10m 30s
# 721:	learn: 0.4708035	total: 27m 12s	remaining: 10m 28s
# 722:	learn: 0.4707982	total: 27m 14s	remaining: 10m 26s
# 723:	learn: 0.4707954	total: 27m 16s	remaining: 10m 23s
# 724:	learn: 0.4707872	total: 27m 18s	remaining: 10m 21s
# 725:	learn: 0.4707838	total: 27m 20s	remaining: 10m 19s
# 726:	learn: 0.4707798	total: 27m 23s	remaining: 10m 17s
# 727:	learn: 0.4707754	total: 27m 24s	remaining: 10m 14s
# 728:	learn: 0.4707705	total: 27m 27s	remaining: 10m 12s
# 729:	learn: 0.4707687	total: 27m 29s	remaining: 10m 9s
# 730:	learn: 0.4707651	total: 27m 31s	remaining: 10m 7s
# 731:	learn: 0.4707593	total: 27m 33s	remaining: 10m 5s
# 732:	learn: 0.4707433	total: 27m 36s	remaining: 10m 3s
# 733:	learn: 0.4707392	total: 27m 38s	remaining: 10m 1s
# 734:	learn: 0.4707360	total: 27m 40s	remaining: 9m 58s
# 735:	learn: 0.4707315	total: 27m 42s	remaining: 9m 56s
# 736:	learn: 0.4707233	total: 27m 44s	remaining: 9m 53s
# 737:	learn: 0.4707154	total: 27m 46s	remaining: 9m 51s
# 738:	learn: 0.4707053	total: 27m 48s	remaining: 9m 49s
# 739:	learn: 0.4706962	total: 27m 50s	remaining: 9m 47s
# 740:	learn: 0.4706906	total: 27m 52s	remaining: 9m 44s
# 741:	learn: 0.4706866	total: 27m 54s	remaining: 9m 42s
# 742:	learn: 0.4706832	total: 27m 57s	remaining: 9m 40s
# 743:	learn: 0.4706786	total: 27m 59s	remaining: 9m 37s
# 744:	learn: 0.4706718	total: 28m 1s	remaining: 9m 35s
# 745:	learn: 0.4706637	total: 28m 4s	remaining: 9m 33s
# 746:	learn: 0.4706592	total: 28m 6s	remaining: 9m 31s
# 747:	learn: 0.4706527	total: 28m 8s	remaining: 9m 28s
# 748:	learn: 0.4706483	total: 28m 10s	remaining: 9m 26s
# 749:	learn: 0.4706445	total: 28m 12s	remaining: 9m 24s
# 750:	learn: 0.4706397	total: 28m 15s	remaining: 9m 22s
# 751:	learn: 0.4706336	total: 28m 17s	remaining: 9m 19s
# 752:	learn: 0.4706287	total: 28m 19s	remaining: 9m 17s
# 753:	learn: 0.4706240	total: 28m 21s	remaining: 9m 15s
# 754:	learn: 0.4706182	total: 28m 23s	remaining: 9m 12s
# 755:	learn: 0.4706104	total: 28m 26s	remaining: 9m 10s
# 756:	learn: 0.4706058	total: 28m 29s	remaining: 9m 8s
# 757:	learn: 0.4705995	total: 28m 31s	remaining: 9m 6s
# 758:	learn: 0.4705957	total: 28m 33s	remaining: 9m 4s
# 759:	learn: 0.4705903	total: 28m 35s	remaining: 9m 1s
# 760:	learn: 0.4705871	total: 28m 38s	remaining: 8m 59s
# 761:	learn: 0.4705792	total: 28m 40s	remaining: 8m 57s
# 762:	learn: 0.4705721	total: 28m 42s	remaining: 8m 54s
# 763:	learn: 0.4705656	total: 28m 44s	remaining: 8m 52s
# 764:	learn: 0.4705588	total: 28m 46s	remaining: 8m 50s
# 765:	learn: 0.4705531	total: 28m 48s	remaining: 8m 48s
# 766:	learn: 0.4705484	total: 28m 50s	remaining: 8m 45s
# 767:	learn: 0.4705434	total: 28m 52s	remaining: 8m 43s
# 768:	learn: 0.4705398	total: 28m 54s	remaining: 8m 41s
# 769:	learn: 0.4705357	total: 28m 57s	remaining: 8m 38s
# 770:	learn: 0.4705323	total: 29m	remaining: 8m 36s
# 771:	learn: 0.4705295	total: 29m 2s	remaining: 8m 34s
# 772:	learn: 0.4705252	total: 29m 4s	remaining: 8m 32s
# 773:	learn: 0.4705207	total: 29m 7s	remaining: 8m 30s
# 774:	learn: 0.4705185	total: 29m 9s	remaining: 8m 27s
# 775:	learn: 0.4705156	total: 29m 11s	remaining: 8m 25s
# 776:	learn: 0.4705122	total: 29m 13s	remaining: 8m 23s
# 777:	learn: 0.4705078	total: 29m 15s	remaining: 8m 20s
# 778:	learn: 0.4705000	total: 29m 17s	remaining: 8m 18s
# 779:	learn: 0.4704955	total: 29m 19s	remaining: 8m 16s
# 780:	learn: 0.4704905	total: 29m 21s	remaining: 8m 13s
# 781:	learn: 0.4704854	total: 29m 23s	remaining: 8m 11s
# 782:	learn: 0.4704825	total: 29m 25s	remaining: 8m 9s
# 783:	learn: 0.4704781	total: 29m 27s	remaining: 8m 7s
# 784:	learn: 0.4704743	total: 29m 29s	remaining: 8m 4s
# 785:	learn: 0.4704684	total: 29m 31s	remaining: 8m 2s
# 786:	learn: 0.4704640	total: 29m 33s	remaining: 8m
# 787:	learn: 0.4704597	total: 29m 35s	remaining: 7m 57s
# 788:	learn: 0.4704546	total: 29m 37s	remaining: 7m 55s
# 789:	learn: 0.4704509	total: 29m 39s	remaining: 7m 53s
# 790:	learn: 0.4704445	total: 29m 41s	remaining: 7m 50s
# 791:	learn: 0.4704376	total: 29m 44s	remaining: 7m 48s
# 792:	learn: 0.4704304	total: 29m 45s	remaining: 7m 46s
# 793:	learn: 0.4704283	total: 29m 47s	remaining: 7m 43s
# 794:	learn: 0.4704246	total: 29m 49s	remaining: 7m 41s
# 795:	learn: 0.4704182	total: 29m 51s	remaining: 7m 39s
# 796:	learn: 0.4704136	total: 29m 53s	remaining: 7m 36s
# 797:	learn: 0.4704082	total: 29m 56s	remaining: 7m 34s
# 798:	learn: 0.4704049	total: 29m 58s	remaining: 7m 32s
# 799:	learn: 0.4703971	total: 30m 1s	remaining: 7m 30s
# 800:	learn: 0.4703902	total: 30m 3s	remaining: 7m 28s
# 801:	learn: 0.4703862	total: 30m 5s	remaining: 7m 25s
# 802:	learn: 0.4703802	total: 30m 7s	remaining: 7m 23s
# 803:	learn: 0.4703754	total: 30m 10s	remaining: 7m 21s
# 804:	learn: 0.4703692	total: 30m 12s	remaining: 7m 18s
# 805:	learn: 0.4703643	total: 30m 14s	remaining: 7m 16s
# 806:	learn: 0.4703610	total: 30m 16s	remaining: 7m 14s
# 807:	learn: 0.4703573	total: 30m 18s	remaining: 7m 12s
# 808:	learn: 0.4703506	total: 30m 21s	remaining: 7m 9s
# 809:	learn: 0.4703469	total: 30m 23s	remaining: 7m 7s
# 810:	learn: 0.4703444	total: 30m 25s	remaining: 7m 5s
# 811:	learn: 0.4703416	total: 30m 27s	remaining: 7m 3s
# 812:	learn: 0.4703380	total: 30m 30s	remaining: 7m
# 813:	learn: 0.4703350	total: 30m 32s	remaining: 6m 58s
# 814:	learn: 0.4703270	total: 30m 34s	remaining: 6m 56s
# 815:	learn: 0.4703222	total: 30m 35s	remaining: 6m 53s
# 816:	learn: 0.4703172	total: 30m 37s	remaining: 6m 51s
# 817:	learn: 0.4703131	total: 30m 40s	remaining: 6m 49s
# 818:	learn: 0.4703067	total: 30m 42s	remaining: 6m 47s
# 819:	learn: 0.4703029	total: 30m 45s	remaining: 6m 45s
# 820:	learn: 0.4702951	total: 30m 47s	remaining: 6m 42s
# 821:	learn: 0.4702901	total: 30m 49s	remaining: 6m 40s
# 822:	learn: 0.4702876	total: 30m 52s	remaining: 6m 38s
# 823:	learn: 0.4702833	total: 30m 54s	remaining: 6m 36s
# 824:	learn: 0.4702790	total: 30m 56s	remaining: 6m 33s
# 825:	learn: 0.4702741	total: 30m 59s	remaining: 6m 31s
# 826:	learn: 0.4702694	total: 31m 1s	remaining: 6m 29s
# 827:	learn: 0.4702620	total: 31m 3s	remaining: 6m 27s
# 828:	learn: 0.4702580	total: 31m 4s	remaining: 6m 24s
# 829:	learn: 0.4702514	total: 31m 6s	remaining: 6m 22s
# 830:	learn: 0.4702487	total: 31m 8s	remaining: 6m 19s
# 831:	learn: 0.4702457	total: 31m 10s	remaining: 6m 17s
# 832:	learn: 0.4702413	total: 31m 12s	remaining: 6m 15s
# 833:	learn: 0.4702375	total: 31m 15s	remaining: 6m 13s
# 834:	learn: 0.4702335	total: 31m 17s	remaining: 6m 10s
# 835:	learn: 0.4702309	total: 31m 19s	remaining: 6m 8s
# 836:	learn: 0.4702282	total: 31m 21s	remaining: 6m 6s
# 837:	learn: 0.4702236	total: 31m 22s	remaining: 6m 3s
# 838:	learn: 0.4702167	total: 31m 24s	remaining: 6m 1s
# 839:	learn: 0.4702121	total: 31m 26s	remaining: 5m 59s
# 840:	learn: 0.4702071	total: 31m 28s	remaining: 5m 57s
# 841:	learn: 0.4702032	total: 31m 31s	remaining: 5m 54s
# 842:	learn: 0.4701992	total: 31m 34s	remaining: 5m 52s
# 843:	learn: 0.4701925	total: 31m 36s	remaining: 5m 50s
# 844:	learn: 0.4701872	total: 31m 38s	remaining: 5m 48s
# 845:	learn: 0.4701823	total: 31m 40s	remaining: 5m 46s
# 846:	learn: 0.4701748	total: 31m 43s	remaining: 5m 43s
# 847:	learn: 0.4701704	total: 31m 45s	remaining: 5m 41s
# 848:	learn: 0.4701652	total: 31m 47s	remaining: 5m 39s
# 849:	learn: 0.4701621	total: 31m 50s	remaining: 5m 37s
# 850:	learn: 0.4701572	total: 31m 52s	remaining: 5m 34s
# 851:	learn: 0.4701538	total: 31m 54s	remaining: 5m 32s
# 852:	learn: 0.4701483	total: 31m 56s	remaining: 5m 30s
# 853:	learn: 0.4701463	total: 31m 58s	remaining: 5m 27s
# 854:	learn: 0.4701398	total: 32m 1s	remaining: 5m 25s
# 855:	learn: 0.4701349	total: 32m 3s	remaining: 5m 23s
# 856:	learn: 0.4701300	total: 32m 5s	remaining: 5m 21s
# 857:	learn: 0.4701262	total: 32m 7s	remaining: 5m 19s
# 858:	learn: 0.4701235	total: 32m 9s	remaining: 5m 16s
# 859:	learn: 0.4701203	total: 32m 11s	remaining: 5m 14s
# 860:	learn: 0.4701152	total: 32m 13s	remaining: 5m 12s
# 861:	learn: 0.4701119	total: 32m 15s	remaining: 5m 9s
# 862:	learn: 0.4701092	total: 32m 17s	remaining: 5m 7s
# 863:	learn: 0.4701057	total: 32m 20s	remaining: 5m 5s
# 864:	learn: 0.4701019	total: 32m 22s	remaining: 5m 3s
# 865:	learn: 0.4700972	total: 32m 24s	remaining: 5m
# 866:	learn: 0.4700938	total: 32m 26s	remaining: 4m 58s
# 867:	learn: 0.4700904	total: 32m 29s	remaining: 4m 56s
# 868:	learn: 0.4700849	total: 32m 30s	remaining: 4m 54s
# 869:	learn: 0.4700823	total: 32m 32s	remaining: 4m 51s
# 870:	learn: 0.4700742	total: 32m 35s	remaining: 4m 49s
# 871:	learn: 0.4700710	total: 32m 37s	remaining: 4m 47s
# 872:	learn: 0.4700659	total: 32m 38s	remaining: 4m 44s
# 873:	learn: 0.4700611	total: 32m 40s	remaining: 4m 42s
# 874:	learn: 0.4700568	total: 32m 43s	remaining: 4m 40s
# 875:	learn: 0.4700524	total: 32m 45s	remaining: 4m 38s
# 876:	learn: 0.4700466	total: 32m 47s	remaining: 4m 36s
# 877:	learn: 0.4700436	total: 32m 50s	remaining: 4m 33s
# 878:	learn: 0.4700412	total: 32m 51s	remaining: 4m 31s
# 879:	learn: 0.4700377	total: 32m 53s	remaining: 4m 29s
# 880:	learn: 0.4700342	total: 32m 56s	remaining: 4m 26s
# 881:	learn: 0.4700315	total: 32m 58s	remaining: 4m 24s
# 882:	learn: 0.4700272	total: 33m	remaining: 4m 22s
# 883:	learn: 0.4700232	total: 33m 2s	remaining: 4m 20s
# 884:	learn: 0.4700206	total: 33m 3s	remaining: 4m 17s
# 885:	learn: 0.4700166	total: 33m 6s	remaining: 4m 15s
# 886:	learn: 0.4700140	total: 33m 7s	remaining: 4m 13s
# 887:	learn: 0.4700101	total: 33m 10s	remaining: 4m 11s
# 888:	learn: 0.4700036	total: 33m 12s	remaining: 4m 8s
# 889:	learn: 0.4699991	total: 33m 14s	remaining: 4m 6s
# 890:	learn: 0.4699961	total: 33m 16s	remaining: 4m 4s
# 891:	learn: 0.4699921	total: 33m 18s	remaining: 4m 1s
# 892:	learn: 0.4699899	total: 33m 20s	remaining: 3m 59s
# 893:	learn: 0.4699868	total: 33m 23s	remaining: 3m 57s
# 894:	learn: 0.4699850	total: 33m 25s	remaining: 3m 55s
# 895:	learn: 0.4699808	total: 33m 27s	remaining: 3m 52s
# 896:	learn: 0.4699781	total: 33m 29s	remaining: 3m 50s
# 897:	learn: 0.4699744	total: 33m 31s	remaining: 3m 48s
# 898:	learn: 0.4699675	total: 33m 33s	remaining: 3m 46s
# 899:	learn: 0.4699649	total: 33m 35s	remaining: 3m 43s
# 900:	learn: 0.4699619	total: 33m 37s	remaining: 3m 41s
# 901:	learn: 0.4699592	total: 33m 40s	remaining: 3m 39s
# 902:	learn: 0.4699554	total: 33m 42s	remaining: 3m 37s
# 903:	learn: 0.4699515	total: 33m 44s	remaining: 3m 35s
# 904:	learn: 0.4699480	total: 33m 47s	remaining: 3m 32s
# 905:	learn: 0.4699441	total: 33m 49s	remaining: 3m 30s
# 906:	learn: 0.4699384	total: 33m 52s	remaining: 3m 28s
# 907:	learn: 0.4699297	total: 33m 54s	remaining: 3m 26s
# 908:	learn: 0.4699274	total: 33m 56s	remaining: 3m 23s
# 909:	learn: 0.4699231	total: 33m 58s	remaining: 3m 21s
# 910:	learn: 0.4699190	total: 34m	remaining: 3m 19s
# 911:	learn: 0.4699167	total: 34m 2s	remaining: 3m 17s
# 912:	learn: 0.4699137	total: 34m 5s	remaining: 3m 14s
# 913:	learn: 0.4699044	total: 34m 7s	remaining: 3m 12s
# 914:	learn: 0.4699007	total: 34m 9s	remaining: 3m 10s
# 915:	learn: 0.4698972	total: 34m 11s	remaining: 3m 8s
# 916:	learn: 0.4698946	total: 34m 13s	remaining: 3m 5s
# 917:	learn: 0.4698899	total: 34m 15s	remaining: 3m 3s
# 918:	learn: 0.4698864	total: 34m 17s	remaining: 3m 1s
# 919:	learn: 0.4698837	total: 34m 19s	remaining: 2m 59s
# 920:	learn: 0.4698808	total: 34m 22s	remaining: 2m 56s
# 921:	learn: 0.4698766	total: 34m 23s	remaining: 2m 54s
# 922:	learn: 0.4698717	total: 34m 26s	remaining: 2m 52s
# 923:	learn: 0.4698692	total: 34m 28s	remaining: 2m 50s
# 924:	learn: 0.4698666	total: 34m 30s	remaining: 2m 47s
# 925:	learn: 0.4698644	total: 34m 32s	remaining: 2m 45s
# 926:	learn: 0.4698613	total: 34m 34s	remaining: 2m 43s
# 927:	learn: 0.4698581	total: 34m 36s	remaining: 2m 41s
# 928:	learn: 0.4698541	total: 34m 38s	remaining: 2m 38s
# 929:	learn: 0.4698440	total: 34m 40s	remaining: 2m 36s
# 930:	learn: 0.4698392	total: 34m 43s	remaining: 2m 34s
# 931:	learn: 0.4698378	total: 34m 45s	remaining: 2m 32s
# 932:	learn: 0.4698349	total: 34m 46s	remaining: 2m 29s
# 933:	learn: 0.4698308	total: 34m 48s	remaining: 2m 27s
# 934:	learn: 0.4698250	total: 34m 51s	remaining: 2m 25s
# 935:	learn: 0.4698196	total: 34m 53s	remaining: 2m 23s
# 936:	learn: 0.4698126	total: 34m 55s	remaining: 2m 20s
# 937:	learn: 0.4698083	total: 34m 57s	remaining: 2m 18s
# 938:	learn: 0.4698054	total: 34m 59s	remaining: 2m 16s
# 939:	learn: 0.4698013	total: 35m 1s	remaining: 2m 14s
# 940:	learn: 0.4697967	total: 35m 3s	remaining: 2m 11s
# 941:	learn: 0.4697912	total: 35m 6s	remaining: 2m 9s
# 942:	learn: 0.4697846	total: 35m 8s	remaining: 2m 7s
# 943:	learn: 0.4697817	total: 35m 11s	remaining: 2m 5s
# 944:	learn: 0.4697771	total: 35m 13s	remaining: 2m 3s
# 945:	learn: 0.4697734	total: 35m 15s	remaining: 2m
# 946:	learn: 0.4697700	total: 35m 17s	remaining: 1m 58s
# 947:	learn: 0.4697665	total: 35m 19s	remaining: 1m 56s
# 948:	learn: 0.4697608	total: 35m 21s	remaining: 1m 54s
# 949:	learn: 0.4697553	total: 35m 23s	remaining: 1m 51s
# 950:	learn: 0.4697515	total: 35m 25s	remaining: 1m 49s
# 951:	learn: 0.4697462	total: 35m 27s	remaining: 1m 47s
# 952:	learn: 0.4697447	total: 35m 29s	remaining: 1m 45s
# 953:	learn: 0.4697397	total: 35m 31s	remaining: 1m 42s
# 954:	learn: 0.4697359	total: 35m 33s	remaining: 1m 40s
# 955:	learn: 0.4697332	total: 35m 35s	remaining: 1m 38s
# 956:	learn: 0.4697300	total: 35m 38s	remaining: 1m 36s
# 957:	learn: 0.4697275	total: 35m 40s	remaining: 1m 33s
# 958:	learn: 0.4697246	total: 35m 42s	remaining: 1m 31s
# 959:	learn: 0.4697189	total: 35m 44s	remaining: 1m 29s
# 960:	learn: 0.4697132	total: 35m 46s	remaining: 1m 27s
# 961:	learn: 0.4697100	total: 35m 49s	remaining: 1m 24s
# 962:	learn: 0.4697062	total: 35m 51s	remaining: 1m 22s
# 963:	learn: 0.4697025	total: 35m 53s	remaining: 1m 20s
# 964:	learn: 0.4696982	total: 35m 55s	remaining: 1m 18s
# 965:	learn: 0.4696947	total: 35m 57s	remaining: 1m 15s
# 966:	learn: 0.4696919	total: 35m 59s	remaining: 1m 13s
# 967:	learn: 0.4696876	total: 36m 1s	remaining: 1m 11s
# 968:	learn: 0.4696842	total: 36m 3s	remaining: 1m 9s
# 969:	learn: 0.4696815	total: 36m 5s	remaining: 1m 6s
# 970:	learn: 0.4696767	total: 36m 7s	remaining: 1m 4s
# 971:	learn: 0.4696746	total: 36m 9s	remaining: 1m 2s
# 972:	learn: 0.4696660	total: 36m 11s	remaining: 1m
# 973:	learn: 0.4696631	total: 36m 13s	remaining: 58s
# 974:	learn: 0.4696577	total: 36m 15s	remaining: 55.8s
# 975:	learn: 0.4696536	total: 36m 17s	remaining: 53.6s
# 976:	learn: 0.4696523	total: 36m 20s	remaining: 51.3s
# 977:	learn: 0.4696497	total: 36m 22s	remaining: 49.1s
# 978:	learn: 0.4696475	total: 36m 24s	remaining: 46.9s
# 979:	learn: 0.4696441	total: 36m 27s	remaining: 44.6s
# 980:	learn: 0.4696403	total: 36m 29s	remaining: 42.4s
# 981:	learn: 0.4696339	total: 36m 31s	remaining: 40.2s
# 982:	learn: 0.4696276	total: 36m 33s	remaining: 37.9s
# 983:	learn: 0.4696248	total: 36m 36s	remaining: 35.7s
# 984:	learn: 0.4696223	total: 36m 38s	remaining: 33.5s
# 985:	learn: 0.4696189	total: 36m 40s	remaining: 31.2s
# 986:	learn: 0.4696162	total: 36m 43s	remaining: 29s
# 987:	learn: 0.4696140	total: 36m 45s	remaining: 26.8s
# 988:	learn: 0.4696104	total: 36m 47s	remaining: 24.6s
# 989:	learn: 0.4696069	total: 36m 50s	remaining: 22.3s
# 990:	learn: 0.4696025	total: 36m 52s	remaining: 20.1s
# 991:	learn: 0.4695996	total: 36m 54s	remaining: 17.9s
# 992:	learn: 0.4695970	total: 36m 56s	remaining: 15.6s
# 993:	learn: 0.4695932	total: 36m 58s	remaining: 13.4s
# 994:	learn: 0.4695909	total: 37m	remaining: 11.2s
# 995:	learn: 0.4695882	total: 37m 2s	remaining: 8.93s
# 996:	learn: 0.4695863	total: 37m 5s	remaining: 6.7s
# 997:	learn: 0.4695842	total: 37m 7s	remaining: 4.46s
# 998:	learn: 0.4695791	total: 37m 9s	remaining: 2.23s
# 999:	learn: 0.4695745	total: 37m 12s	remaining: 0us

# %% [markdown]
# Repeating the pipeline for the test set - normalization and context features addition

# %%
def load_encoders():
    feature = 'target_id_hash'
    with open(f'{assaf_path}/label_encoders/{feature}.pickle', 'rb') as handle:
        encoder = pickle.load(handle)
        return encoder
target_id_encoder = load_encoders()
# Out:
# /home/noysal/.conda/envs/py39_torch/lib/python3.9/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.2.2 when using version 1.4.1.post1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
df_submission = pd.read_csv('./submission_example.csv')
df_test = pd.read_csv(f'{assaf_path}/test_file.csv')
df_test_normed = pd.read_csv(f'{assaf_path}/test_file_normalized_with_target_id.csv')
df_test_normed.drop(columns=['Unnamed: 0'], inplace=True)

# %%
def norm_target_id():
    unique_values = df_test['target_id_hash'].unique()
    value_to_code = dict()
    for value in tqdm(unique_values):
        try:
            mapped_value = target_id_encoder.transform([value])[0]
        except ValueError as err:
            mapped_value = target_id_encoder.classes_.shape[0]
        value_to_code[value] = mapped_value
    result = df_test['target_id_hash'].apply(lambda value: value_to_code[value])
    return result


# target_id_normed = norm_target_id()
# df_test_normed['target_id_hash'] = target_id_normed
# df_test_normed.to_csv('./test_file_normalized_with_target_id.csv')

# %% [markdown]
# We concatted the train data (last_x_days) and the test data, and than re-run the context feature extraction. for new categorial values it created a new value, but for previously seen categories it 'retained' the value of the context (last_x_days)

# %%
def add_feature_ctr(feature_1, df_normed, df_to_apply_on):
    """
    reference:
    https://medium.com/unstructured/how-feature-engineering-can-help-you-do-well-in-a-kaggle-competition-part-ii-3645d92282b8
    """
    used_columns = [
        f'{feature_1}_id_hash',
        'target_id_hash', 'page_view_start_time', 'empiric_calibrated_recs'
    ]
    data = pd.concat([last_x_days[used_columns], df_normed[used_columns]])
    latest_views = data.iloc[data.groupby('target_id_hash')['page_view_start_time'].idxmax()]
    latest_views = data.drop_duplicates(subset='target_id_hash', keep='first')
    stats = latest_views.groupby(f'{feature_1}_id_hash').agg({'empiric_calibrated_recs': 'sum', 'target_id_hash': 'count'})
    average_views_of_distinct_ad = np.log2(stats['empiric_calibrated_recs'].sum() / stats['target_id_hash'].sum())
    average_views_of_distict_ad_in_feature = np.log2(1 + (stats['empiric_calibrated_recs'] / stats['target_id_hash']))
    stats[f'{feature_1}_ctr'] = np.minimum((average_views_of_distict_ad_in_feature / average_views_of_distinct_ad), 1)
    stats = stats.reset_index()[[f'{feature_1}_id_hash', f'{feature_1}_ctr']]
    temp_df = data[[f'{feature_1}_id_hash']].merge(stats, on=f'{feature_1}_id_hash', how='left')
    df_to_apply_on[f'{feature_1}_ctr'] = temp_df[f'{feature_1}_ctr']

def add_pair_feature_ctr(feature_1, feature_2, df_normed, df_to_apply_on):
    """
    reference:
    https://medium.com/unstructured/how-feature-engineering-can-help-you-do-well-in-a-kaggle-competition-part-ii-3645d92282b8
    """
    used_columns = [
        f'{feature_1}_id_hash', f'{feature_2}_id_hash',
        'target_id_hash', 'page_view_start_time', 'empiric_calibrated_recs'
    ]
    data = pd.concat([last_x_days[used_columns], df_normed[used_columns]])
    latest_views = data.iloc[data.groupby('target_id_hash')['page_view_start_time'].idxmax()]
    latest_views = data.drop_duplicates(subset='target_id_hash', keep='first')
    stats = latest_views.groupby([f'{feature_1}_id_hash', f'{feature_2}_id_hash']).agg({'empiric_calibrated_recs': 'sum', 'target_id_hash': 'count'})
    average_views_of_distinct_ad = np.log2(stats['empiric_calibrated_recs'].sum() / stats['target_id_hash'].sum())
    average_views_of_distict_ad_in_feature = np.log2(1 + (stats['empiric_calibrated_recs'] / stats['target_id_hash']))
    stats[f'{feature_1}_{feature_2}_ctr'] = np.minimum((average_views_of_distict_ad_in_feature / average_views_of_distinct_ad), 1)
    stats = stats.reset_index()[[f'{feature_1}_id_hash', f'{feature_2}_id_hash', f'{feature_1}_{feature_2}_ctr']]
    temp_df = data[[f'{feature_1}_id_hash', f'{feature_2}_id_hash']].merge(stats, on=[f'{feature_1}_id_hash', f'{feature_2}_id_hash'], how='left')
    df_to_apply_on[f'{feature_1}_{feature_2}_ctr'] = temp_df[f'{feature_1}_{feature_2}_ctr']

def get_test_features():
    testset = df_test.copy(deep=True)
    testset['country_code'].fillna('Null', inplace=True)
    testset['region'].fillna('Null', inplace=True)
    test_features = testset[[
        'page_view_start_time',
        # 'user_id_hash',
        # 'target_id_hash',
        'syndicator_id_hash',
        'campaign_id_hash',
        'empiric_calibrated_recs',
        'empiric_clicks',
        'target_item_taxonomy',
        'placement_id_hash',
        'user_recs',
        'user_clicks',
        'user_target_recs',
        'publisher_id_hash',
        'source_id_hash',
        'source_item_type',
        'browser_platform',
        'os_family',
        'country_code',
        'region',
        'day_of_week',
        'time_of_day',
        'gmt_offset'
    ]]
    # generate general target item taxonomy
    test_features['target_item_taxonomy_upper'] = test_features['target_item_taxonomy'].str.split('~').str[0]
    # target item ctr
    test_features['target_item_ctr'] = test_features['empiric_clicks'].divide(test_features['empiric_calibrated_recs'], fill_value=0) 
    # user ctr
    test_features['user_ctr'] = test_features['user_clicks'].divide(test_features['user_recs'], fill_value=0)
    # target item frequency
    test_features['item_presented_to_user_frequency'] = test_features['user_target_recs'].divide(test_features['user_recs'], fill_value=0)
    # aggregation
    test_features['item_be_clicked_by_user'] = test_features['user_ctr'] * test_features['target_item_ctr'] * test_features['item_presented_to_user_frequency']
    # take the timestamp, shift to the local time by gmt offset, look at the hour of the day and generate categorical feature "local part of the day"
    # apply_gmt_offset
    gmt_offsets = test_features['gmt_offset'].replace(9999, 0).astype(str).apply(format_time_offset)
    dt_series = pd.to_datetime(test_features['page_view_start_time'], unit='us')
    gmt_offsets = pd.to_timedelta(gmt_offsets)
    dt_with_offset = dt_series + gmt_offsets
    test_features['local_day_part'] = dt_with_offset.apply(categorize_time)

    # binary feature for cold and warm user
    test_features['user_type'] = (test_features['user_recs'] > 0).apply(lambda x: 'warm' if x else 'cold')
    # generate "category ctr"
    # generate ctr for estimate for features_ctr
    features_ctr = ['campaign', 'syndicator', 'placement', 'publisher', 'source']
    for feature in features_ctr:
        add_feature_ctr(feature, df_test_normed, test_features)
    # generate ctr for pair wise estimate
    for feature_1, feature_2 in list(combinations(features_ctr, 2)):
        add_pair_feature_ctr(feature_1, feature_2, df_test_normed, test_features)
    return test_features
test_features = get_test_features()
# Out:
# /tmp/ipykernel_24180/2247021210.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_features['target_item_taxonomy_upper'] = test_features['target_item_taxonomy'].str.split('~').str[0]
# /tmp/ipykernel_24180/2247021210.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_features['target_item_ctr'] = test_features['empiric_clicks'].divide(test_features['empiric_calibrated_recs'], fill_value=0)

# %%
test_features = test_features[[
    # 'user_id_hash',
    # 'target_id_hash',
    'syndicator_id_hash',
    'campaign_id_hash',
    'empiric_calibrated_recs',
    'empiric_clicks',
    'target_item_taxonomy',
    'placement_id_hash',
    'user_recs',
    'user_clicks',
    'user_target_recs',
    'publisher_id_hash',
    'source_id_hash',
    'source_item_type',
    'browser_platform',
    'os_family',
    'country_code',
    'region',
    'day_of_week',
    'time_of_day',
    'gmt_offset',
    'target_item_taxonomy_upper',
    'target_item_ctr',
    'user_ctr',
    'item_presented_to_user_frequency',
    'item_be_clicked_by_user',
    'local_day_part',
    'user_type',
    'campaign_ctr',
    'syndicator_ctr',
    'placement_ctr',
    'publisher_ctr',
    'source_ctr',
    'campaign_syndicator_ctr',
    'campaign_placement_ctr',
    'campaign_publisher_ctr',
    'campaign_source_ctr',
    'syndicator_placement_ctr',
    'syndicator_publisher_ctr',
    'syndicator_source_ctr',
    'placement_publisher_ctr',
    'placement_source_ctr',
    'publisher_source_ctr',
]].to_numpy()

# %% [markdown]
#  Running the catboost model on the newly extracted test set features

# %%
preds_proba = model.predict_proba(test_features)

# %%
def report_submission():
    pred = preds_proba[:,1]
    pred_df = pd.DataFrame(pred)
    pred_df.reset_index(inplace=True)
    pred_df.columns = ['Id','Predicted']
    pred_df.to_csv('5_days_freq_norm.csv',index=False)
report_submission()

# %%
# Saving processed data for easy retrival
data = {'X_train' : last_x_days_features,
        'y_train' : last_x_days_ground_truth,
        'X_test' : test_features }
with open('optuna_5_days_X-train_Y-train_X-Test_dict.pickle', 'wb') as f:
    pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
